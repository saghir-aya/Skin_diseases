# %%
import tensorflow as tf 
physical_devices = tf.config.list_physical_devices("GPU")
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
import random, numpy as np, os
#import tensorflow_datasets as tfds
#tfds.disable_progress_bar()
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.config.run_functions_eagerly(True)
def config_gpu(mp=False):
    print('Eager Model : ', tf.executing_eagerly())
    print('TensorFlow Cuda Built Test : ', tf.test.is_built_with_cuda)
    print('TensorFlow GPU Detected : ', tf.test.gpu_device_name())
    print('TensorFlow System Cuda Version : ', tf.sysconfig.get_build_info()["cuda_version"])
    print('TensorFlow System CudNN Version : ', tf.sysconfig.get_build_info()["cudnn_version"] )

    AUTO = tf.data.AUTOTUNE
    #GPUS = tf.config.list_physical_devices('GPU')
    GPUS = tf.config.experimental.list_physical_devices('GPU')
    if len(GPUS) > 0:
        tf.config.set_visible_devices(physical_devices[0:1], 'GPU')
    if GPUS:
        try:
            for GPU in GPUS:
                tf.config.experimental.set_memory_growth(GPU, True)
                logical_gpus = tf.config.list_logical_devices('GPU')
                print(len(GPUS), "Physical GPUs,", len(logical_gpus), "Logical GPUs") 
        except RuntimeError as  RE:
            print(RE)
    if mp:
        tf.keras.mixed_precision.set_global_policy('mixed_float16')
        print('Mixed precision enabled')
        
#tf.keras.utils.set_random_seed(100)
config_gpu(mp=False)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Eager Model :  True
# TensorFlow Cuda Built Test :  <function is_built_with_cuda at 0x0000027D1BFC55E0>
# TensorFlow GPU Detected :  /device:GPU:0
# TensorFlow System Cuda Version :  64_112
# TensorFlow System CudNN Version :  64_8
# 2 Physical GPUs, 1 Logical GPUs
# Physical devices cannot be modified after being initialized

# %% [markdown]
# # <a id='intro'>Plan</a>
# #### [Wavelet with residual block](#the_destination)
# #### [Efficient-net](#Efficient_net)
# #### [Ensemblelearning](#Ensemble_learning)
# #### [Metrics with Graph](#graph)
# #### [Grad-CAM](#Gradcam)
# #### [Result Metrics](#metrics)

# %% [markdown]
# # <a id=''>TF Dataset and Preprocess</a>

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from tensorflow.keras import callbacks 
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from keras.layers import Lambda
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
import shutil
from sklearn.metrics import  precision_score, recall_score, accuracy_score,classification_report ,confusion_matrix
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile

# %%
import os, cv2
import random, math
import numpy as np 
import pandas as pd
from PIL import Image
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

import tensorflow, keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
#from keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD, Adam
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K

import warnings
warnings.filterwarnings('ignore')

# %%
train_path = r'C:\Users\ADMIN\Documents\base_dir\train_dir'
#train_path = r'C:\Users\ADMIN\Documents\base_dir\train_dir_test'
test_path = r'C:\Users\ADMIN\Documents\base_dir\base_dir\val_dir'
batch_size = 16
train_batch_size = 4
#train_batch_size = 4
val_batch_size = 4
image_size = 224

# %%
def custom_augmentation(np_tensor):

  def random_contrast(np_tensor):
    return np.array(tf.image.random_contrast(np_tensor, 0.5, 2))

  def random_saturation(np_tensor):
    return np.array(tf.image.random_saturation(np_tensor, 0.2, 3))

  def random_crop(np_tensor):
    #cropped height between 70% to 130% of an original height
    new_height = int(np.random.uniform(0.7, 1.30) * np_tensor.shape[0])
    #cropped width between 70% to 130% of an original width
    new_width = int(np.random.uniform(0.7, 1.30) * np_tensor.shape[1])
    # resize to new height and width
    cropped = tf.image.resize_with_crop_or_pad(np_tensor, new_height, new_width)
    return np.array(tf.image.resize(cropped, np_tensor.shape[:2]))

  def gaussian_noise(np_tensor):
    mean = 0
    # variance: randomly between 1 to 25
    var = np.random.randint(1, 26)
    # sigma is square root of the variance value
    noise = np.random.normal(mean,var**0.5,np_tensor.shape)
    return np.clip(np_tensor + noise, 0, 255).astype('int')

  def cutout(np_tensor):
    cutout_height = int(np.random.uniform(0.1, 0.2) * np_tensor.shape[0])
    cutout_width = int(np.random.uniform(0.1, 0.2) * np_tensor.shape[1])
    cutout_height_point = np.random.randint(np_tensor.shape[0]-cutout_height)
    cutout_width_point = np.random.randint(np_tensor.shape[1]-cutout_width)
    np_tensor[cutout_height_point:cutout_height_point+cutout_height, cutout_width_point:cutout_width_point+cutout_width, :] = 127
    return np_tensor

  if (np.random.uniform() < 0.1):
    np_tensor = random_contrast(np_tensor)
  if (np.random.uniform() < 0.1):
    np_tensor = random_saturation(np_tensor)
  if (np.random.uniform() < 0.2):
    np_tensor = random_crop(np_tensor)
  if (np.random.uniform() < 0.2):
    np_tensor = gaussian_noise(np_tensor)
  if (np.random.uniform() < 0.3):
    np_tensor = cutout(np_tensor)
  return np.array(np_tensor)

# %%
datagen = ImageDataGenerator(#preprocessing_function=custom_augmentation,
                            rescale=1./255,
                             preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
                            horizontal_flip = True,
                            vertical_flip=True
)
datagen1 = ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
                             rescale=1./255,)
                             #horizontal_flip = True,
                             #vertical_flip=True,)


train_batches = datagen.flow_from_directory(train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=train_batch_size,)
                                           #subset='training')

valid_batches = datagen.flow_from_directory(test_path,
                                            target_size=(image_size,image_size),
                                            batch_size=val_batch_size,)

test_batches = datagen1.flow_from_directory(test_path,
                                            target_size=(image_size,image_size),
                                            batch_size=32,
                                            shuffle=False,)
                                          #subset='validation')
# Out:
# Found 38569 images belonging to 7 classes.
# Found 938 images belonging to 7 classes.
# Found 938 images belonging to 7 classes.

# %%
#densneet
# %matplotlib inline
image, label = next(train_batches)
plt.figure(figsize=(20,10))
inline = 4
for i in range(inline):
    #print(image.size())
    plt.subplot(2, inline, i%inline +1)
    plt.axis('off')
    plt.imshow(image[i])
    #plt.title(f'Label: {label}')
    plt.subplot(2, inline, i%inline +5)
    plt.axis('off')
    plt.imshow(image[i].astype(np.uint8))

# %% [markdown]
# # Configuration

# %%
# Setting TPU as main device for training, if you get warnings while working with tpu's ignore them.

DEVICE = 'TPU'
if DEVICE == 'TPU':
    print('connecting to TPU...')
    try:        
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print('Could not connect to TPU')
        tpu = None

    if tpu:
        try:
            print('Initializing  TPU...')
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print('TPU initialized')
        except _:
            print('Failed to initialize TPU!')
    else:
        DEVICE = 'GPU'

if DEVICE != 'TPU':
    print('Using default strategy for CPU and single GPU')
    strategy = tf.distribute.get_strategy()

if DEVICE == 'GPU':
    print('Num GPUs Available: ',
          len(tf.config.experimental.list_physical_devices('GPU')))

print('REPLICAS: ', strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# connecting to TPU...
# Could not connect to TPU
# Using default strategy for CPU and single GPU
# Num GPUs Available:  2
# REPLICAS:  1

# %%
cfg = dict(
           batch_size=4,
           img_size=384,
    
           lr_start=0.000005,
           lr_max=0.00000125,
           lr_min=0.000001,
           lr_rampup=5,
           lr_sustain=0,
           lr_decay=0.8,
           epochs=12,
    
           transform_prob=1.0,
           rot=180.0,
           shr=2.0,
           hzoom=8.0,
           wzoom=8.0,
           hshift=8.0,
           wshift=8.0,
    
           optimizer='adam',
           label_smooth_fac=0.05,
           tta_steps=20
            
        )

# %% [markdown]
# # <a id='the_destination'>Wavelet with residual block</a>
# #### [Return Contents](#intro)

# %%
# batch operation usng tensor slice
def WaveletTransformAxisY(batch_img):
    odd_img  = batch_img[:,0::2]
    even_img = batch_img[:,1::2]
    L = (odd_img + even_img) / 2.0
    H = K.abs(odd_img - even_img)
    return L, H

def WaveletTransformAxisX(batch_img):
    # transpose + fliplr
    tmp_batch = K.permute_dimensions(batch_img, [0, 2, 1])[:,:,::-1]
    _dst_L, _dst_H = WaveletTransformAxisY(tmp_batch)
    # transpose + flipud
    dst_L = K.permute_dimensions(_dst_L, [0, 2, 1])[:,::-1,...]
    dst_H = K.permute_dimensions(_dst_H, [0, 2, 1])[:,::-1,...]
    return dst_L, dst_H

# %%
def Wavelet(batch_image):
    # make channel first image
    batch_image = K.permute_dimensions(batch_image, [0, 3, 1, 2])
    r = batch_image[:,0]
    g = batch_image[:,1]
    b = batch_image[:,2]

    # level 1 decomposition
    wavelet_L, wavelet_H = WaveletTransformAxisY(r)
    r_wavelet_LL, r_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    r_wavelet_HL, r_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(g)
    g_wavelet_LL, g_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    g_wavelet_HL, g_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(b)
    b_wavelet_LL, b_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    b_wavelet_HL, b_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_data = [r_wavelet_LL, r_wavelet_LH, r_wavelet_HL, r_wavelet_HH, 
                    g_wavelet_LL, g_wavelet_LH, g_wavelet_HL, g_wavelet_HH,
                    b_wavelet_LL, b_wavelet_LH, b_wavelet_HL, b_wavelet_HH]
    transform_batch = K.stack(wavelet_data, axis=1)

    # level 2 decomposition
    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(r_wavelet_LL)
    r_wavelet_LL2, r_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    r_wavelet_HL2, r_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(g_wavelet_LL)
    g_wavelet_LL2, g_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    g_wavelet_HL2, g_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(b_wavelet_LL)
    b_wavelet_LL2, b_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    b_wavelet_HL2, b_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)


    wavelet_data_l2 = [r_wavelet_LL2, r_wavelet_LH2, r_wavelet_HL2, r_wavelet_HH2, 
                    g_wavelet_LL2, g_wavelet_LH2, g_wavelet_HL2, g_wavelet_HH2,
                    b_wavelet_LL2, b_wavelet_LH2, b_wavelet_HL2, b_wavelet_HH2]
    transform_batch_l2 = K.stack(wavelet_data_l2, axis=1)

    # level 3 decomposition
    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(r_wavelet_LL2)
    r_wavelet_LL3, r_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    r_wavelet_HL3, r_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(g_wavelet_LL2)
    g_wavelet_LL3, g_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    g_wavelet_HL3, g_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL2)
    b_wavelet_LL3, b_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    b_wavelet_HL3, b_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_data_l3 = [r_wavelet_LL3, r_wavelet_LH3, r_wavelet_HL3, r_wavelet_HH3, 
                    g_wavelet_LL3, g_wavelet_LH3, g_wavelet_HL3, g_wavelet_HH3,
                    b_wavelet_LL3, b_wavelet_LH3, b_wavelet_HL3, b_wavelet_HH3]
    transform_batch_l3 = K.stack(wavelet_data_l3, axis=1)

    # level 4 decomposition
    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(r_wavelet_LL3)
    r_wavelet_LL4, r_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    r_wavelet_HL4, r_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(g_wavelet_LL3)
    g_wavelet_LL4, g_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    g_wavelet_HL4, g_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL3)
    b_wavelet_LL4, b_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    b_wavelet_HL4, b_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)


    wavelet_data_l4 = [r_wavelet_LL4, r_wavelet_LH4, r_wavelet_HL4, r_wavelet_HH4, 
                    g_wavelet_LL4, g_wavelet_LH4, g_wavelet_HL4, g_wavelet_HH4,
                    b_wavelet_LL4, b_wavelet_LH4, b_wavelet_HL4, b_wavelet_HH4]
    transform_batch_l4 = K.stack(wavelet_data_l4, axis=1)

    # print('shape before')
    # print(transform_batch.shape)
    # print(transform_batch_l2.shape)
    # print(transform_batch_l3.shape)
    # print(transform_batch_l4.shape)

    decom_level_1 = K.permute_dimensions(transform_batch, [0, 2, 3, 1])
    decom_level_2 = K.permute_dimensions(transform_batch_l2, [0, 2, 3, 1])
    decom_level_3 = K.permute_dimensions(transform_batch_l3, [0, 2, 3, 1])
    decom_level_4 = K.permute_dimensions(transform_batch_l4, [0, 2, 3, 1])
    
    # print('shape after')
    # print(decom_level_1.shape)
    # print(decom_level_2.shape)
    # print(decom_level_3.shape)
    # print(decom_level_4.shape)
    return [decom_level_1, decom_level_2,decom_level_3,decom_level_4]


def Wavelet_out_shape(input_shapes):
    # print('in to shape')
    return [tuple([None, 112, 112, 12]), tuple([None, 56, 56, 12]), 
            tuple([None, 28, 28, 12]), tuple([None, 14, 14, 12])]

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

# Fonction pour créer un bloc résiduel
def residual_block(x, filters, strides=(1, 1)):
    # Couches de convolution du bloc résiduel
    shortcut = x
    x = Conv2D(filters, kernel_size=(3, 3), strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    # Connexion résiduelle
    if strides != (1, 1) or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, kernel_size=(1, 1), strides=strides, padding='same')(shortcut)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x
class SpatialAttention(tf.keras.layers.Layer):
      def __init__(self, kernel_size):
        super(SpatialAttention, self).__init__()
        self.kernel_size = kernel_size
        
        def build(self, input_shape):
            self.conv2d = tf.keras.layers.Conv2D(filters = 1,
                    kernel_size=self.kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)

        def call(self, inputs):
            
            # AvgPool
            avg_pool = tf.keras.layers.Lambda(lambda x: tf.keras.backend.mean(x, axis=3, keepdims=True))(inputs)
            
            # MaxPool
            max_pool = tf.keras.layers.Lambda(lambda x: tf.keras.backend.max(x, axis=3, keepdims=True))(inputs)

            attention = tf.keras.layers.Concatenate(axis=3)([avg_pool, max_pool])

            attention = self.conv2d(attention)


            return tf.keras.layers.multiply([inputs, attention]) 
class ChannelAttention(tf.keras.layers.Layer):
      def __init__(self, filters, ratio):
        super(ChannelAttention, self).__init__()
        self.filters = filters
        self.ratio = ratio

        def build(self, input_shape):
            self.shared_layer_one = tf.keras.layers.Dense(self.filters//self.ratio,
                             activation='relu', kernel_initializer='he_normal', 
                              use_bias=True, 
                              bias_initializer='zeros')
            self.shared_layer_two = tf.keras.layers.Dense(self.filters,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')

        def call(self, inputs):
            # AvgPool
            avg_pool = tf.keras.layers.GlobalAveragePooling2D()(inputs)
            

            avg_pool = self.shared_layer_one(avg_pool)
            avg_pool = self.shared_layer_two(avg_pool)

            # MaxPool
            max_pool = tf.keras.layers.GlobalMaxPooling2D()(inputs)
            max_pool = tf.keras.layers.Reshape((1,1,filters))(max_pool)

            max_pool = shared_layer_one(max_pool)
            max_pool = shared_layer_two(max_pool)


            attention = tf.keras.layers.Add()([avg_pool,max_pool])
            attention = tf.keras.layers.Activation('sigmoid')(attention)
            
            return tf.keras.layers.Multiply()([inputs, attention])
def get_wavelet_cnn_model():
    input_shape = 224, 224, 3

    input_ = Input(input_shape, name='the_input')
    wavelet = Lambda(Wavelet, Wavelet_out_shape, name='wavelet')
    input_l1, input_l2, input_l3, input_l4 = wavelet(input_)

    # Adjust the number of channels in wavelet decomposition output
    input_l1 = Conv2D(64, kernel_size=(1, 1), padding='same', name='adjust_channels_l1')(input_l1)
    input_l2 = Conv2D(64, kernel_size=(1, 1), padding='same', name='adjust_channels_l2')(input_l2)
    input_l3 = Conv2D(64, kernel_size=(1, 1), padding='same', name='adjust_channels_l3')(input_l3)
    input_l4 = Conv2D(64, kernel_size=(1, 1), padding='same', name='adjust_channels_l4')(input_l4)

    # Architecture ResNet avec les blocs résiduels et les blocs de transformation en ondelettes

    x = input_
    x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)



    # Niveau 1
    x = input_l1
    relu_a = residual_block(x, filters=64, strides=(2, 2))
    #relu_a=ChannelAttention(128, 8)(relu_a)
    relu_a=SpatialAttention(10)(relu_a)

    # Niveau 2
    x = input_l2
    for _ in range(2):
        relu_1_2 = residual_block(x, filters=64)
    #relu_1_2=ChannelAttention(128, 8)(relu_1_2)
    relu_1_2=SpatialAttention(10)(relu_1_2)
      
    print("conc")
    concate_level_2 = concatenate([relu_1_2, relu_a])
    relu_2_2 = residual_block(concate_level_2, filters=128, strides=(2, 2))
    print(relu_2_2)
        
        
    x = input_l3
    relu_b_2 = residual_block(x, filters=64)
    for _ in range(2):
        relu_b_2 = residual_block(relu_b_2, filters=128)
    #relu_b_2=ChannelAttention(128, 8)(relu_b_2)
    relu_b_2=SpatialAttention(10)(relu_b_2)

    concate_level_3 = concatenate([relu_2_2, relu_b_2])
    print("conc")
    print(concate_level_3)
    relu_3_2 = residual_block(concate_level_3, filters=256, strides=(2, 2))
    
    # Niveau 3
    x = input_l4
    relu_c_3 = residual_block(x, filters=64)
    for _ in range(2):
        relu_c_3 = residual_block(relu_c_3, filters=256)
    #relu_c_3=ChannelAttention(128, 8)(relu_c_3)
    relu_c_3=SpatialAttention(10)(relu_c_3)
    concate_level_4 = concatenate([relu_3_2, relu_c_3])
    print("conc")
    print(concate_level_4)
    conv_4 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_4')(concate_level_4)
    norm_4 = BatchNormalization(name='norm_4')(conv_4)
    relu_4 = Activation('relu', name='relu_4')(norm_4)

    conv_4_2 = Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_4_2')(relu_4)
    norm_4_2 = BatchNormalization(name='norm_4_2')(conv_4_2)
    relu_4_2 = Activation('relu', name='relu_4_2')(norm_4_2)

    conv_5_1 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_5_1')(relu_4_2)
    norm_5_1 = BatchNormalization(name='norm_5_1')(conv_5_1)
    relu_5_1 = Activation('relu', name='relu_5_1')(norm_5_1)

    pool_5_1 = AveragePooling2D(pool_size=(7, 7), strides=1, padding='same', name='avg_pool_5_1')(relu_5_1)
    flat_5_1 = Flatten(name='flat_5_1')(pool_5_1) 
    
    fc_5 = Dense(2048, name='fc_5')(flat_5_1)
    norm_5 = BatchNormalization(name='norm_5')(fc_5)
    relu_5 = Activation('relu', name='relu_5')(norm_5)
    drop_5 = Dropout(0.5, name='drop_5')(relu_5)

    fc_6 = Dense(2048, name='fc_6')(drop_5)
    norm_6 = BatchNormalization(name='norm_6')(fc_6)
    relu_6 = Activation('relu', name='relu_6')(norm_6)
    drop_6 = Dropout(0.5, name='drop_6')(relu_6)

    output = Dense(7, activation='softmax', name='fc_7')(drop_6)
    
    model = Model(inputs=input_, outputs=output)

    return model

# %%
#wavelet model
wavelet = get_wavelet_cnn_model()
# Out:
# conc
# KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 128), dtype=tf.float32, name=None), name='activation_8/Relu:0', description="created by layer 'activation_8'")
# conc
# KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 256), dtype=tf.float32, name=None), name='concatenate_1/concat:0', description="created by layer 'concatenate_1'")
# conc
# KerasTensor(type_spec=TensorSpec(shape=(None, 14, 14, 512), dtype=tf.float32, name=None), name='concatenate_2/concat:0', description="created by layer 'concatenate_2'")

# %%
import tensorflow as tf 
display(tf.keras.utils.plot_model(wavelet, 
                                  show_shapes=True, 
                                  show_layer_names=True,
                                  expand_nested=True))

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers

# Multi-Atrous Branch
class MultiAtrous(keras.Model):
    def __init__(self, 
                 dilation_rates=[6, 12, 18], 
                 upsampling=1, 
                 kernel_size=3, 
                 padding="same",  **kwargs):
        super(MultiAtrous, self).__init__(name='MultiAtrous', **kwargs)
        self.dilation_rates = dilation_rates
        self.kernel_size = kernel_size 
        self.upsampling = upsampling
        self.padding = padding
      
        # Dilated Convolutions                     
        self.dilated_convs = [
                              layers.Conv2D(
                                  filters       = int(1024 / 4), 
                                  kernel_size   = self.kernel_size,  
                                  padding       = self.padding, 
                                  dilation_rate = rate
                                ) for rate in self.dilation_rates
                             ]
        
        # Global Average Pooling Branch 
        self.gap_branch = keras.Sequential(
            [
                layers.GlobalAveragePooling2D(keepdims=True),
                layers.Conv2D(int(1024 / 2), kernel_size=1),
                layers.Activation('relu'),
                layers.UpSampling2D(size=self.upsampling, interpolation="bilinear")
            ] , name='gap_branch'
        )
        
    def call(self, inputs, training=None, **kwargs):
        local_feature = []
        for dilated_conv in self.dilated_convs:
            x = dilated_conv(inputs) 
            x = self.gap_branch(x)
            local_feature.append(x)
        return tf.concat(local_feature, axis=-1)

    def get_config(self):
        config = {
            'dilation_rates': self.dilation_rates,
            'kernel_size'   : self.kernel_size,
            'padding'       : self.padding,
            'upsampling'    : self.upsampling
        }
        base_config = super(MultiAtrous, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
class GeneralizedMeanPooling2D(layers.Layer):
    def __init__(self, init_norm=3.0, normalize=False, epsilon=1e-6, **kwargs):
        self.init_norm = init_norm
        self.normalize = normalize
        self.epsilon   = epsilon
        super(GeneralizedMeanPooling2D, self).__init__(**kwargs)

    def build(self, input_shape):
        self.p = self.add_weight(name="norms", 
                                 shape=(input_shape[-1],),
                                 initializer=keras.initializers.constant(self.init_norm),
                                 trainable=True)
        super(GeneralizedMeanPooling2D, self).build(input_shape)

    def call(self, inputs):
        x = tf.abs(tf.maximum(self.epsilon, inputs))
        x = tf.pow(x, self.p)
        x = tf.reduce_mean(x, axis=[1,2], keepdims=False) 
        x = tf.pow(x, (1.0 / self.p))
        if self.normalize:
            x = tf.nn.l2_normalize(x, 1)
        return x

    def get_config(self):
        config = {
            'init_norm' : self.init_norm,
            'normalize' : self.normalize,
            'epsilon'   : self.epsilon
        }
        base_config = super(GeneralizedMeanPooling2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
class SkinNet(keras.Model):
    def __init__(self, backbone=None, num_classes=1, activation=None, **kwargs):
        super(SkinNet, self).__init__(name='SkinNet', **kwargs)
        # Number of classes 
        self.num_classes = num_classes
        self.activation  = activation
        
        # Base blcoks 
        self.base = backbone
        self.base_input_shape  = self.base.input_shape[0][1]

        self.glob_branch_pool = keras.Sequential(
            [
                GeneralizedMeanPooling2D(),
                layers.Dense(1024, activation=None)
            ], 
            name='GlobalBranchPooling'
        )
        
        # Head block
        self.classifier = keras.Sequential(
            [
                #layers.GlobalAveragePooling2D(name='HeadGAP'),
                layers.Dense(self.num_classes, activation = self.activation)
            ], 
            name='Classifiers'
        )
       
    # forwarding the computation 
    def call(self, inputs, training=None, **kwargs):
        # Get tensor from target layers 
        to_global= self.base(inputs)

        # Pass the received tensor to Top building blocks 
        global_feat    = self.glob_branch_pool(to_global)
        return self.classifier(global_feat)
    """
    def train_step(self, data):
        return train_step_sam(self, data, rho=0.05)
    """

    def build_graph(self):
        x = keras.Input(shape=(self.base_input_shape, self.base_input_shape, 3))
        return keras.Model(inputs=[x], outputs=self.call(x))

# %%
from tensorflow.keras import applications, layers, Model, Input

for l in wavelet.layers:
    print(l.name, l.output_shape)
# Out:
# the_input [(None, 224, 224, 3)]
# wavelet [(None, 112, 112, 12), (None, 56, 56, 12), (None, 28, 28, 12), (None, 14, 14, 12)]
# adjust_channels_l3 (None, 28, 28, 64)
# conv2d_11 (None, 28, 28, 64)
# batch_normalization_9 (None, 28, 28, 64)
# activation_9 (None, 28, 28, 64)
# conv2d_12 (None, 28, 28, 64)
# batch_normalization_10 (None, 28, 28, 64)
# adjust_channels_l2 (None, 56, 56, 64)
# adjust_channels_l1 (None, 112, 112, 64)
# add_4 (None, 28, 28, 64)
# conv2d_6 (None, 56, 56, 64)
# conv2d_1 (None, 56, 56, 64)
# activation_10 (None, 28, 28, 64)
# batch_normalization_5 (None, 56, 56, 64)
# batch_normalization_1 (None, 56, 56, 64)
# conv2d_13 (None, 28, 28, 128)
# adjust_channels_l4 (None, 14, 14, 64)
# activation_5 (None, 56, 56, 64)
# activation_1 (None, 56, 56, 64)
# batch_normalization_11 (None, 28, 28, 128)
# conv2d_21 (None, 14, 14, 64)
# conv2d_7 (None, 56, 56, 64)
# conv2d_2 (None, 56, 56, 64)
# activation_11 (None, 28, 28, 128)
# batch_normalization_17 (None, 14, 14, 64)
# batch_normalization_6 (None, 56, 56, 64)
# batch_normalization_2 (None, 56, 56, 64)
# conv2d_3 (None, 56, 56, 64)
# conv2d_14 (None, 28, 28, 128)
# activation_17 (None, 14, 14, 64)
# add_2 (None, 56, 56, 64)
# add (None, 56, 56, 64)
# batch_normalization_12 (None, 28, 28, 128)
# conv2d_15 (None, 28, 28, 128)
# conv2d_22 (None, 14, 14, 64)
# activation_6 (None, 56, 56, 64)
# activation_2 (None, 56, 56, 64)
# add_5 (None, 28, 28, 128)
# batch_normalization_18 (None, 14, 14, 64)
# spatial_attention_1 (None, 56, 56, 64)
# spatial_attention (None, 56, 56, 64)
# activation_12 (None, 28, 28, 128)
# add_8 (None, 14, 14, 64)
# concatenate (None, 56, 56, 128)
# conv2d_16 (None, 28, 28, 128)
# activation_18 (None, 14, 14, 64)
# conv2d_8 (None, 28, 28, 128)
# batch_normalization_13 (None, 28, 28, 128)
# conv2d_23 (None, 14, 14, 256)
# batch_normalization_7 (None, 28, 28, 128)
# activation_13 (None, 28, 28, 128)
# batch_normalization_19 (None, 14, 14, 256)
# activation_7 (None, 28, 28, 128)
# conv2d_17 (None, 28, 28, 128)
# activation_19 (None, 14, 14, 256)
# conv2d_9 (None, 28, 28, 128)
# batch_normalization_14 (None, 28, 28, 128)
# conv2d_24 (None, 14, 14, 256)
# batch_normalization_8 (None, 28, 28, 128)
# conv2d_10 (None, 28, 28, 128)
# add_6 (None, 28, 28, 128)
# batch_normalization_20 (None, 14, 14, 256)
# conv2d_25 (None, 14, 14, 256)
# add_3 (None, 28, 28, 128)
# activation_14 (None, 28, 28, 128)
# add_9 (None, 14, 14, 256)
# activation_8 (None, 28, 28, 128)
# spatial_attention_2 (None, 28, 28, 128)
# activation_20 (None, 14, 14, 256)
# concatenate_1 (None, 28, 28, 256)
# conv2d_26 (None, 14, 14, 256)
# conv2d_18 (None, 14, 14, 256)
# batch_normalization_21 (None, 14, 14, 256)
# batch_normalization_15 (None, 14, 14, 256)
# activation_21 (None, 14, 14, 256)
# activation_15 (None, 14, 14, 256)
# conv2d_27 (None, 14, 14, 256)
# conv2d_19 (None, 14, 14, 256)
# batch_normalization_22 (None, 14, 14, 256)
# batch_normalization_16 (None, 14, 14, 256)
# conv2d_20 (None, 14, 14, 256)
# add_10 (None, 14, 14, 256)
# add_7 (None, 14, 14, 256)
# activation_22 (None, 14, 14, 256)
# activation_16 (None, 14, 14, 256)
# spatial_attention_3 (None, 14, 14, 256)
# concatenate_2 (None, 14, 14, 512)
# conv_4 (None, 14, 14, 256)
# norm_4 (None, 14, 14, 256)
# relu_4 (None, 14, 14, 256)
# conv_4_2 (None, 7, 7, 256)
# norm_4_2 (None, 7, 7, 256)
# relu_4_2 (None, 7, 7, 256)
# conv_5_1 (None, 7, 7, 128)
# norm_5_1 (None, 7, 7, 128)
# relu_5_1 (None, 7, 7, 128)
# avg_pool_5_1 (None, 7, 7, 128)
# flat_5_1 (None, 6272)
# fc_5 (None, 2048)
# norm_5 (None, 2048)
# relu_5 (None, 2048)
# drop_5 (None, 2048)
# fc_6 (None, 2048)
# norm_6 (None, 2048)
# relu_6 (None, 2048)
# drop_6 (None, 2048)
# fc_7 (None, 7)

# %%
#9bel mnni kente dayra wavelet 3adi bla residual block kent dayra ghir model.input ms 3tatni error 'nonetype' dkchi 3lash
#beddeltha b hadi model.inputs
new_base = keras.Model(
    [wavelet.inputs], 
    [
        wavelet.get_layer('relu_4').output # for global branch (None, 14, 14, 256)
    ], 
    name='Wavelet'
)

# %%
skin_net = SkinNet(new_base, num_classes=7, activation='softmax')
skin_net.build_graph().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  Wavelet (Functional)        (None, 14, 14, 256)       5512256
#
#  GlobalBranchPooling (Sequen  (None, 1024)             263424
#  tial)
#
#  Classifiers (Sequential)    (None, 7)                 7175
#
# =================================================================
# Total params: 5,782,855
# Trainable params: 5,776,711
# Non-trainable params: 6,144
# _________________________________________________________________

# %%
import keras.backend as K
import tensorflow as tf

def categorical_focal_loss(gamma=2.0, alpha=0.25):
    """
    Implementation of Focal Loss from the paper in multiclass classification
    Formula:
        loss = -alpha*((1-p)^gamma)*log(p)
    Parameters:
        alpha -- the same as wighting factor in balanced cross entropy
        gamma -- focusing parameter for modulating factor (1-p)
    Default value:
        gamma -- 2.0 as mentioned in the paper
        alpha -- 0.25 as mentioned in the paper
    """
    def focal_loss(y_true, y_pred):
        # Define epsilon so that the backpropagation will not result in NaN
        # for 0 divisor case
        epsilon = K.epsilon()
        # Add the epsilon to prediction value
        #y_pred = y_pred + epsilon
        # Clip the prediction value
        y_pred = K.clip(y_pred, epsilon, 1.0-epsilon)
        # Calculate cross entropy
        cross_entropy = -y_true*K.log(y_pred)
        # Calculate weight that consists of  modulating factor and weighting factor
        weight = alpha * y_true * K.pow((1-y_pred), gamma)
        # Calculate focal loss
        loss = weight * cross_entropy
        # Sum the losses in mini_batch
        loss = K.sum(loss, axis=1)
        return loss
    
    return focal_loss

# %%
tf.config.optimizer.set_jit(True)
def compileNewModel():
    
    ''' Configuring the model with losses and metrics. '''    
    
    with strategy.scope():
        model = skin_net

    with strategy.scope():
        model.compile(optimizer='adam', loss=categorical_focal_loss(), 
                      metrics=['accuracy'])
        #tf.keras.metrics.AUC(name='auc')
    return model

def getLearnRateCallback(cfg):
    
    ''' Using callbacks for learning rate adjustments. '''
    
    lr_start = cfg['lr_start']
    lr_max = cfg['lr_max'] * strategy.num_replicas_in_sync * cfg['batch_size']
    lr_min = cfg['lr_min']
    lr_rampup = cfg['lr_rampup']
    lr_sustain = cfg['lr_sustain']
    lr_decay = cfg['lr_decay']

    def lrfn(epoch):
        if epoch < lr_rampup:
            lr = (lr_max - lr_start) / lr_rampup * epoch + lr_start
        elif epoch < lr_rampup + lr_sustain:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_rampup -
                                                lr_sustain) + lr_min
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback


def learnModel(model, ds_train, cfg, ds_val):
    
    ''' Fitting things together for training '''
    
    filepath1 = "modelFocal"
    checkpoint = ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)
    callbacks = [getLearnRateCallback(cfg), checkpoint]

    history = model.fit(ds_train,
                        validation_data=ds_val,
                        verbose=True,
                        epochs=400,
                        callbacks=callbacks)

    return history

# %% [markdown]
# model = compileNewModel()
# history = learnModel(model, train_batches, cfg, valid_batches)

# %%
model = compileNewModel()
history = learnModel(model, train_batches, cfg, valid_batches)
# Out:
# Epoch 1/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.5491
# Epoch 1: val_accuracy improved from -inf to 0.83795, saving model to modelFocal
# 9643/9643 [==============================] - 294s 29ms/step - loss: 0.1825 - accuracy: 0.5491 - val_loss: 0.0635 - val_accuracy: 0.8380 - lr: 5.0000e-06
# Epoch 2/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.6565
# Epoch 2: val_accuracy improved from 0.83795 to 0.84968, saving model to modelFocal
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.1267 - accuracy: 0.6565 - val_loss: 0.0615 - val_accuracy: 0.8497 - lr: 5.0000e-06
# Epoch 3/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.6929
# Epoch 3: val_accuracy improved from 0.84968 to 0.85608, saving model to modelFocal
# 9643/9643 [==============================] - 286s 30ms/step - loss: 0.1072 - accuracy: 0.6929 - val_loss: 0.0571 - val_accuracy: 0.8561 - lr: 5.0000e-06
# Epoch 4/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.7163
# Epoch 4: val_accuracy improved from 0.85608 to 0.86141, saving model to modelFocal
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0961 - accuracy: 0.7163 - val_loss: 0.0517 - val_accuracy: 0.8614 - lr: 5.0000e-06
# Epoch 5/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.7376
# Epoch 5: val_accuracy did not improve from 0.86141
# 9643/9643 [==============================] - 296s 31ms/step - loss: 0.0868 - accuracy: 0.7376 - val_loss: 0.0495 - val_accuracy: 0.8593 - lr: 5.0000e-06
# Epoch 6/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.7586
# Epoch 6: val_accuracy improved from 0.86141 to 0.86674, saving model to modelFocal
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0796 - accuracy: 0.7586 - val_loss: 0.0502 - val_accuracy: 0.8667 - lr: 5.0000e-06
# Epoch 7/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.7717
# Epoch 7: val_accuracy did not improve from 0.86674
# 9643/9643 [==============================] - 322s 33ms/step - loss: 0.0723 - accuracy: 0.7717 - val_loss: 0.0483 - val_accuracy: 0.8667 - lr: 4.2000e-06
# Epoch 8/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0677 - accuracy: 0.7871
# Epoch 8: val_accuracy improved from 0.86674 to 0.87740, saving model to modelFocal
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0677 - accuracy: 0.7871 - val_loss: 0.0453 - val_accuracy: 0.8774 - lr: 3.5600e-06
# Epoch 9/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.7991
# Epoch 9: val_accuracy did not improve from 0.87740
# 9643/9643 [==============================] - 293s 30ms/step - loss: 0.0638 - accuracy: 0.7991 - val_loss: 0.0474 - val_accuracy: 0.8710 - lr: 3.0480e-06
# Epoch 10/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0597 - accuracy: 0.8106
# Epoch 10: val_accuracy improved from 0.87740 to 0.87953, saving model to modelFocal
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0597 - accuracy: 0.8105 - val_loss: 0.0439 - val_accuracy: 0.8795 - lr: 2.6384e-06
# Epoch 11/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.8160
# Epoch 11: val_accuracy did not improve from 0.87953
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0572 - accuracy: 0.8160 - val_loss: 0.0453 - val_accuracy: 0.8785 - lr: 2.3107e-06
# Epoch 12/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.8226
# Epoch 12: val_accuracy did not improve from 0.87953
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0541 - accuracy: 0.8226 - val_loss: 0.0478 - val_accuracy: 0.8763 - lr: 2.0486e-06
# Epoch 13/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.8283
# Epoch 13: val_accuracy did not improve from 0.87953
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0517 - accuracy: 0.8283 - val_loss: 0.0452 - val_accuracy: 0.8774 - lr: 1.8389e-06
# Epoch 14/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.8357
# Epoch 14: val_accuracy did not improve from 0.87953
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0504 - accuracy: 0.8357 - val_loss: 0.0474 - val_accuracy: 0.8763 - lr: 1.6711e-06
# Epoch 15/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.8376
# Epoch 15: val_accuracy improved from 0.87953 to 0.88060, saving model to modelFocal
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0491 - accuracy: 0.8376 - val_loss: 0.0462 - val_accuracy: 0.8806 - lr: 1.5369e-06
# Epoch 16/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.8414
# Epoch 16: val_accuracy did not improve from 0.88060
# 9643/9643 [==============================] - 288s 30ms/step - loss: 0.0479 - accuracy: 0.8414 - val_loss: 0.0455 - val_accuracy: 0.8753 - lr: 1.4295e-06
# Epoch 17/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.8425
# Epoch 17: val_accuracy improved from 0.88060 to 0.88699, saving model to modelFocal
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0467 - accuracy: 0.8425 - val_loss: 0.0442 - val_accuracy: 0.8870 - lr: 1.3436e-06
# Epoch 18/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0452 - accuracy: 0.8498
# Epoch 18: val_accuracy did not improve from 0.88699
# 9643/9643 [==============================] - 281s 29ms/step - loss: 0.0452 - accuracy: 0.8498 - val_loss: 0.0461 - val_accuracy: 0.8849 - lr: 1.2749e-06
# Epoch 19/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.8496
# Epoch 19: val_accuracy did not improve from 0.88699
# 9643/9643 [==============================] - 314s 33ms/step - loss: 0.0446 - accuracy: 0.8496 - val_loss: 0.0489 - val_accuracy: 0.8774 - lr: 1.2199e-06
# Epoch 20/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.8526
# Epoch 20: val_accuracy did not improve from 0.88699
# 9643/9643 [==============================] - 304s 32ms/step - loss: 0.0433 - accuracy: 0.8527 - val_loss: 0.0460 - val_accuracy: 0.8763 - lr: 1.1759e-06
# Epoch 21/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.8575
# Epoch 21: val_accuracy did not improve from 0.88699
# 9643/9643 [==============================] - 318s 33ms/step - loss: 0.0426 - accuracy: 0.8575 - val_loss: 0.0432 - val_accuracy: 0.8870 - lr: 1.1407e-06
# Epoch 22/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.8573
# Epoch 22: val_accuracy did not improve from 0.88699
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0420 - accuracy: 0.8573 - val_loss: 0.0453 - val_accuracy: 0.8785 - lr: 1.1126e-06
# Epoch 23/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.8613
# Epoch 23: val_accuracy improved from 0.88699 to 0.88806, saving model to modelFocal
# 9643/9643 [==============================] - 293s 30ms/step - loss: 0.0412 - accuracy: 0.8613 - val_loss: 0.0436 - val_accuracy: 0.8881 - lr: 1.0901e-06
# Epoch 24/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.8618
# Epoch 24: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 316s 33ms/step - loss: 0.0405 - accuracy: 0.8618 - val_loss: 0.0450 - val_accuracy: 0.8881 - lr: 1.0721e-06
# Epoch 25/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0394 - accuracy: 0.8663
# Epoch 25: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0394 - accuracy: 0.8663 - val_loss: 0.0449 - val_accuracy: 0.8881 - lr: 1.0576e-06
# Epoch 26/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.8675
# Epoch 26: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 298s 31ms/step - loss: 0.0390 - accuracy: 0.8675 - val_loss: 0.0424 - val_accuracy: 0.8859 - lr: 1.0461e-06
# Epoch 27/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.8682
# Epoch 27: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 293s 30ms/step - loss: 0.0385 - accuracy: 0.8682 - val_loss: 0.0488 - val_accuracy: 0.8763 - lr: 1.0369e-06
# Epoch 28/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.8700
# Epoch 28: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 319s 33ms/step - loss: 0.0379 - accuracy: 0.8700 - val_loss: 0.0458 - val_accuracy: 0.8817 - lr: 1.0295e-06
# Epoch 29/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.8726
# Epoch 29: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 313s 32ms/step - loss: 0.0376 - accuracy: 0.8726 - val_loss: 0.0448 - val_accuracy: 0.8849 - lr: 1.0236e-06
# Epoch 30/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.8751
# Epoch 30: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 291s 30ms/step - loss: 0.0365 - accuracy: 0.8751 - val_loss: 0.0459 - val_accuracy: 0.8763 - lr: 1.0189e-06
# Epoch 31/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.8750
# Epoch 31: val_accuracy did not improve from 0.88806
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0364 - accuracy: 0.8751 - val_loss: 0.0465 - val_accuracy: 0.8721 - lr: 1.0151e-06
# Epoch 32/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.8782
# Epoch 32: val_accuracy improved from 0.88806 to 0.89339, saving model to modelFocal
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0353 - accuracy: 0.8781 - val_loss: 0.0428 - val_accuracy: 0.8934 - lr: 1.0121e-06
# Epoch 33/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.8795
# Epoch 33: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0350 - accuracy: 0.8795 - val_loss: 0.0492 - val_accuracy: 0.8859 - lr: 1.0097e-06
# Epoch 34/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.8793
# Epoch 34: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 295s 31ms/step - loss: 0.0346 - accuracy: 0.8793 - val_loss: 0.0454 - val_accuracy: 0.8881 - lr: 1.0077e-06
# Epoch 35/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.8805
# Epoch 35: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 326s 34ms/step - loss: 0.0344 - accuracy: 0.8805 - val_loss: 0.0437 - val_accuracy: 0.8838 - lr: 1.0062e-06
# Epoch 36/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.8841
# Epoch 36: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 318s 33ms/step - loss: 0.0331 - accuracy: 0.8841 - val_loss: 0.0486 - val_accuracy: 0.8774 - lr: 1.0050e-06
# Epoch 37/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.8861
# Epoch 37: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 295s 31ms/step - loss: 0.0328 - accuracy: 0.8861 - val_loss: 0.0472 - val_accuracy: 0.8881 - lr: 1.0040e-06
# Epoch 38/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.8872
# Epoch 38: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0328 - accuracy: 0.8872 - val_loss: 0.0480 - val_accuracy: 0.8891 - lr: 1.0032e-06
# Epoch 39/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.8886
# Epoch 39: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0323 - accuracy: 0.8886 - val_loss: 0.0455 - val_accuracy: 0.8891 - lr: 1.0025e-06
# Epoch 40/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.8870
# Epoch 40: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0319 - accuracy: 0.8870 - val_loss: 0.0438 - val_accuracy: 0.8870 - lr: 1.0020e-06
# Epoch 41/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.8898
# Epoch 41: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0314 - accuracy: 0.8898 - val_loss: 0.0442 - val_accuracy: 0.8913 - lr: 1.0016e-06
# Epoch 42/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.8907
# Epoch 42: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 322s 33ms/step - loss: 0.0310 - accuracy: 0.8907 - val_loss: 0.0431 - val_accuracy: 0.8870 - lr: 1.0013e-06
# Epoch 43/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.8933
# Epoch 43: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0303 - accuracy: 0.8933 - val_loss: 0.0429 - val_accuracy: 0.8891 - lr: 1.0010e-06
# Epoch 44/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.8939
# Epoch 44: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 289s 30ms/step - loss: 0.0298 - accuracy: 0.8939 - val_loss: 0.0447 - val_accuracy: 0.8913 - lr: 1.0008e-06
# Epoch 45/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.8973
# Epoch 45: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 299s 31ms/step - loss: 0.0294 - accuracy: 0.8973 - val_loss: 0.0450 - val_accuracy: 0.8838 - lr: 1.0007e-06
# Epoch 46/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.8990
# Epoch 46: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0285 - accuracy: 0.8990 - val_loss: 0.0467 - val_accuracy: 0.8806 - lr: 1.0005e-06
# Epoch 47/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.8991
# Epoch 47: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0284 - accuracy: 0.8991 - val_loss: 0.0452 - val_accuracy: 0.8934 - lr: 1.0004e-06
# Epoch 48/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.8995
# Epoch 48: val_accuracy did not improve from 0.89339
# 9643/9643 [==============================] - 294s 30ms/step - loss: 0.0282 - accuracy: 0.8995 - val_loss: 0.0429 - val_accuracy: 0.8923 - lr: 1.0003e-06
# Epoch 49/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9014
# Epoch 49: val_accuracy improved from 0.89339 to 0.89552, saving model to modelFocal
# 9643/9643 [==============================] - 304s 31ms/step - loss: 0.0279 - accuracy: 0.9014 - val_loss: 0.0396 - val_accuracy: 0.8955 - lr: 1.0003e-06
# Epoch 50/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9049
# Epoch 50: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0271 - accuracy: 0.9049 - val_loss: 0.0468 - val_accuracy: 0.8859 - lr: 1.0002e-06
# Epoch 51/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9028
# Epoch 51: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 289s 30ms/step - loss: 0.0270 - accuracy: 0.9028 - val_loss: 0.0421 - val_accuracy: 0.8945 - lr: 1.0002e-06
# Epoch 52/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9047
# Epoch 52: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0266 - accuracy: 0.9047 - val_loss: 0.0434 - val_accuracy: 0.8913 - lr: 1.0001e-06
# Epoch 53/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9063
# Epoch 53: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 326s 34ms/step - loss: 0.0262 - accuracy: 0.9063 - val_loss: 0.0468 - val_accuracy: 0.8923 - lr: 1.0001e-06
# Epoch 54/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9060
# Epoch 54: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0261 - accuracy: 0.9060 - val_loss: 0.0463 - val_accuracy: 0.8870 - lr: 1.0001e-06
# Epoch 55/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9075
# Epoch 55: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0258 - accuracy: 0.9075 - val_loss: 0.0451 - val_accuracy: 0.8945 - lr: 1.0001e-06
# Epoch 56/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9083
# Epoch 56: val_accuracy did not improve from 0.89552
# 9643/9643 [==============================] - 325s 34ms/step - loss: 0.0255 - accuracy: 0.9083 - val_loss: 0.0447 - val_accuracy: 0.8913 - lr: 1.0001e-06
# Epoch 57/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9094
# Epoch 57: val_accuracy improved from 0.89552 to 0.90299, saving model to modelFocal
# 9643/9643 [==============================] - 303s 31ms/step - loss: 0.0250 - accuracy: 0.9094 - val_loss: 0.0472 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 58/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9114
# Epoch 58: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 299s 31ms/step - loss: 0.0241 - accuracy: 0.9114 - val_loss: 0.0452 - val_accuracy: 0.8859 - lr: 1.0000e-06
# Epoch 59/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9121
# Epoch 59: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0241 - accuracy: 0.9121 - val_loss: 0.0438 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 60/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9130
# Epoch 60: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 305s 32ms/step - loss: 0.0240 - accuracy: 0.9130 - val_loss: 0.0456 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 61/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9149
# Epoch 61: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0235 - accuracy: 0.9149 - val_loss: 0.0457 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 62/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 0.9149
# Epoch 62: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 308s 32ms/step - loss: 0.0229 - accuracy: 0.9150 - val_loss: 0.0429 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 63/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9168
# Epoch 63: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0228 - accuracy: 0.9168 - val_loss: 0.0437 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 64/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9183
# Epoch 64: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 304s 31ms/step - loss: 0.0226 - accuracy: 0.9183 - val_loss: 0.0455 - val_accuracy: 0.8806 - lr: 1.0000e-06
# Epoch 65/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9185
# Epoch 65: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 293s 30ms/step - loss: 0.0223 - accuracy: 0.9185 - val_loss: 0.0480 - val_accuracy: 0.8795 - lr: 1.0000e-06
# Epoch 66/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9202
# Epoch 66: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0220 - accuracy: 0.9202 - val_loss: 0.0456 - val_accuracy: 0.8859 - lr: 1.0000e-06
# Epoch 67/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 0.9202
# Epoch 67: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 324s 34ms/step - loss: 0.0216 - accuracy: 0.9202 - val_loss: 0.0473 - val_accuracy: 0.8891 - lr: 1.0000e-06
# Epoch 68/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 0.9193
# Epoch 68: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 298s 31ms/step - loss: 0.0215 - accuracy: 0.9193 - val_loss: 0.0459 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 69/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9230
# Epoch 69: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0207 - accuracy: 0.9230 - val_loss: 0.0462 - val_accuracy: 0.8817 - lr: 1.0000e-06
# Epoch 70/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9223
# Epoch 70: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0209 - accuracy: 0.9223 - val_loss: 0.0459 - val_accuracy: 0.8902 - lr: 1.0000e-06
# Epoch 71/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9261
# Epoch 71: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0205 - accuracy: 0.9261 - val_loss: 0.0457 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 72/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9242
# Epoch 72: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 291s 30ms/step - loss: 0.0205 - accuracy: 0.9241 - val_loss: 0.0483 - val_accuracy: 0.8763 - lr: 1.0000e-06
# Epoch 73/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9251
# Epoch 73: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0201 - accuracy: 0.9251 - val_loss: 0.0469 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 74/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9262
# Epoch 74: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0200 - accuracy: 0.9262 - val_loss: 0.0447 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 75/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9269
# Epoch 75: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0195 - accuracy: 0.9269 - val_loss: 0.0502 - val_accuracy: 0.8806 - lr: 1.0000e-06
# Epoch 76/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9304
# Epoch 76: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 304s 32ms/step - loss: 0.0190 - accuracy: 0.9304 - val_loss: 0.0449 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 77/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9292
# Epoch 77: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0189 - accuracy: 0.9292 - val_loss: 0.0471 - val_accuracy: 0.8859 - lr: 1.0000e-06
# Epoch 78/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9310
# Epoch 78: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 291s 30ms/step - loss: 0.0188 - accuracy: 0.9310 - val_loss: 0.0499 - val_accuracy: 0.8817 - lr: 1.0000e-06
# Epoch 79/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9291
# Epoch 79: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0186 - accuracy: 0.9291 - val_loss: 0.0478 - val_accuracy: 0.8817 - lr: 1.0000e-06
# Epoch 80/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9336
# Epoch 80: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0179 - accuracy: 0.9336 - val_loss: 0.0505 - val_accuracy: 0.8891 - lr: 1.0000e-06
# Epoch 81/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9341
# Epoch 81: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 305s 32ms/step - loss: 0.0177 - accuracy: 0.9341 - val_loss: 0.0446 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 82/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9329
# Epoch 82: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 308s 32ms/step - loss: 0.0178 - accuracy: 0.9329 - val_loss: 0.0475 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 83/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9352
# Epoch 83: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 308s 32ms/step - loss: 0.0172 - accuracy: 0.9352 - val_loss: 0.0474 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 84/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9372
# Epoch 84: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 328s 34ms/step - loss: 0.0167 - accuracy: 0.9372 - val_loss: 0.0462 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 85/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9375
# Epoch 85: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 279s 29ms/step - loss: 0.0168 - accuracy: 0.9375 - val_loss: 0.0436 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 86/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9389
# Epoch 86: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0167 - accuracy: 0.9389 - val_loss: 0.0441 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 87/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9383
# Epoch 87: val_accuracy did not improve from 0.90299
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0165 - accuracy: 0.9383 - val_loss: 0.0529 - val_accuracy: 0.8838 - lr: 1.0000e-06
# Epoch 88/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9393
# Epoch 88: val_accuracy improved from 0.90299 to 0.90405, saving model to modelFocal
# 9643/9643 [==============================] - 304s 32ms/step - loss: 0.0163 - accuracy: 0.9393 - val_loss: 0.0440 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 89/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9403
# Epoch 89: val_accuracy did not improve from 0.90405
# 9643/9643 [==============================] - 313s 32ms/step - loss: 0.0159 - accuracy: 0.9403 - val_loss: 0.0434 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 90/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9420
# Epoch 90: val_accuracy did not improve from 0.90405
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0156 - accuracy: 0.9421 - val_loss: 0.0481 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 91/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9401
# Epoch 91: val_accuracy improved from 0.90405 to 0.90512, saving model to modelFocal
# 9643/9643 [==============================] - 323s 34ms/step - loss: 0.0155 - accuracy: 0.9401 - val_loss: 0.0459 - val_accuracy: 0.9051 - lr: 1.0000e-06
# Epoch 92/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9421
# Epoch 92: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 308s 32ms/step - loss: 0.0156 - accuracy: 0.9422 - val_loss: 0.0465 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 93/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9412
# Epoch 93: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 291s 30ms/step - loss: 0.0154 - accuracy: 0.9412 - val_loss: 0.0481 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 94/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9437
# Epoch 94: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 299s 31ms/step - loss: 0.0149 - accuracy: 0.9437 - val_loss: 0.0469 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 95/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9454
# Epoch 95: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 326s 34ms/step - loss: 0.0145 - accuracy: 0.9454 - val_loss: 0.0469 - val_accuracy: 0.8881 - lr: 1.0000e-06
# Epoch 96/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9428
# Epoch 96: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 307s 32ms/step - loss: 0.0147 - accuracy: 0.9428 - val_loss: 0.0502 - val_accuracy: 0.8859 - lr: 1.0000e-06
# Epoch 97/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9453
# Epoch 97: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 292s 30ms/step - loss: 0.0143 - accuracy: 0.9453 - val_loss: 0.0492 - val_accuracy: 0.8859 - lr: 1.0000e-06
# Epoch 98/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9462
# Epoch 98: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 333s 35ms/step - loss: 0.0142 - accuracy: 0.9462 - val_loss: 0.0481 - val_accuracy: 0.8881 - lr: 1.0000e-06
# Epoch 99/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9476
# Epoch 99: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 317s 33ms/step - loss: 0.0140 - accuracy: 0.9476 - val_loss: 0.0504 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 100/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 0.9468
# Epoch 100: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 295s 31ms/step - loss: 0.0143 - accuracy: 0.9468 - val_loss: 0.0492 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 101/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9482
# Epoch 101: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 321s 33ms/step - loss: 0.0132 - accuracy: 0.9482 - val_loss: 0.0441 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 102/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9484
# Epoch 102: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 304s 31ms/step - loss: 0.0135 - accuracy: 0.9484 - val_loss: 0.0455 - val_accuracy: 0.8902 - lr: 1.0000e-06
# Epoch 103/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9505
# Epoch 103: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 306s 32ms/step - loss: 0.0132 - accuracy: 0.9505 - val_loss: 0.0486 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 104/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9502
# Epoch 104: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0127 - accuracy: 0.9502 - val_loss: 0.0491 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 105/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9506
# Epoch 105: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 332s 34ms/step - loss: 0.0128 - accuracy: 0.9506 - val_loss: 0.0450 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 106/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9516
# Epoch 106: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 303s 31ms/step - loss: 0.0127 - accuracy: 0.9516 - val_loss: 0.0464 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 107/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9531
# Epoch 107: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 289s 30ms/step - loss: 0.0126 - accuracy: 0.9531 - val_loss: 0.0497 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 108/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9535
# Epoch 108: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0124 - accuracy: 0.9535 - val_loss: 0.0461 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 109/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9544
# Epoch 109: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0119 - accuracy: 0.9544 - val_loss: 0.0439 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 110/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9552
# Epoch 110: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0118 - accuracy: 0.9552 - val_loss: 0.0485 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 111/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9559
# Epoch 111: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0117 - accuracy: 0.9559 - val_loss: 0.0466 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 112/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9569
# Epoch 112: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 316s 33ms/step - loss: 0.0116 - accuracy: 0.9569 - val_loss: 0.0493 - val_accuracy: 0.8998 - lr: 1.0000e-06
# Epoch 113/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9575
# Epoch 113: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 314s 33ms/step - loss: 0.0113 - accuracy: 0.9575 - val_loss: 0.0487 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 114/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9579
# Epoch 114: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 289s 30ms/step - loss: 0.0111 - accuracy: 0.9579 - val_loss: 0.0483 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 115/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9590
# Epoch 115: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0110 - accuracy: 0.9590 - val_loss: 0.0444 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 116/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9591
# Epoch 116: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 314s 33ms/step - loss: 0.0109 - accuracy: 0.9591 - val_loss: 0.0456 - val_accuracy: 0.8902 - lr: 1.0000e-06
# Epoch 117/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9573
# Epoch 117: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 302s 31ms/step - loss: 0.0110 - accuracy: 0.9573 - val_loss: 0.0522 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 118/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9587
# Epoch 118: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0107 - accuracy: 0.9587 - val_loss: 0.0495 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 119/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9607
# Epoch 119: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 291s 30ms/step - loss: 0.0106 - accuracy: 0.9607 - val_loss: 0.0482 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 120/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9609
# Epoch 120: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 301s 31ms/step - loss: 0.0104 - accuracy: 0.9609 - val_loss: 0.0426 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 121/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9622
# Epoch 121: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 289s 30ms/step - loss: 0.0100 - accuracy: 0.9622 - val_loss: 0.0482 - val_accuracy: 0.8891 - lr: 1.0000e-06
# Epoch 122/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9598
# Epoch 122: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0103 - accuracy: 0.9598 - val_loss: 0.0449 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 123/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9625
# Epoch 123: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 295s 31ms/step - loss: 0.0101 - accuracy: 0.9625 - val_loss: 0.0519 - val_accuracy: 0.8806 - lr: 1.0000e-06
# Epoch 124/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9638
# Epoch 124: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 296s 31ms/step - loss: 0.0097 - accuracy: 0.9638 - val_loss: 0.0447 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 125/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9630
# Epoch 125: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 313s 32ms/step - loss: 0.0097 - accuracy: 0.9630 - val_loss: 0.0481 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 126/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9639
# Epoch 126: val_accuracy did not improve from 0.90512
# 9643/9643 [==============================] - 293s 30ms/step - loss: 0.0095 - accuracy: 0.9639 - val_loss: 0.0480 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 127/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 0.9645
# Epoch 127: val_accuracy improved from 0.90512 to 0.91151, saving model to modelFocal
# 9643/9643 [==============================] - 296s 31ms/step - loss: 0.0093 - accuracy: 0.9645 - val_loss: 0.0458 - val_accuracy: 0.9115 - lr: 1.0000e-06
# Epoch 128/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9644
# Epoch 128: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 294s 30ms/step - loss: 0.0093 - accuracy: 0.9644 - val_loss: 0.0510 - val_accuracy: 0.8891 - lr: 1.0000e-06
# Epoch 129/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9661
# Epoch 129: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 310s 32ms/step - loss: 0.0089 - accuracy: 0.9661 - val_loss: 0.0449 - val_accuracy: 0.9051 - lr: 1.0000e-06
# Epoch 130/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9648
# Epoch 130: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0091 - accuracy: 0.9648 - val_loss: 0.0471 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 131/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9652
# Epoch 131: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0089 - accuracy: 0.9652 - val_loss: 0.0477 - val_accuracy: 0.8923 - lr: 1.0000e-06
# Epoch 132/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9655
# Epoch 132: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 337s 35ms/step - loss: 0.0089 - accuracy: 0.9655 - val_loss: 0.0519 - val_accuracy: 0.8902 - lr: 1.0000e-06
# Epoch 133/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9667
# Epoch 133: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 292s 30ms/step - loss: 0.0089 - accuracy: 0.9667 - val_loss: 0.0509 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 134/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9662
# Epoch 134: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 296s 31ms/step - loss: 0.0088 - accuracy: 0.9662 - val_loss: 0.0487 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 135/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9675
# Epoch 135: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 286s 30ms/step - loss: 0.0084 - accuracy: 0.9675 - val_loss: 0.0498 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 136/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9677
# Epoch 136: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0084 - accuracy: 0.9677 - val_loss: 0.0504 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 137/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9694
# Epoch 137: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 321s 33ms/step - loss: 0.0082 - accuracy: 0.9694 - val_loss: 0.0481 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 138/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9703
# Epoch 138: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 305s 32ms/step - loss: 0.0079 - accuracy: 0.9703 - val_loss: 0.0491 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 139/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9692
# Epoch 139: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 312s 32ms/step - loss: 0.0079 - accuracy: 0.9692 - val_loss: 0.0498 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 140/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9722
# Epoch 140: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 290s 30ms/step - loss: 0.0077 - accuracy: 0.9722 - val_loss: 0.0511 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 141/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9711
# Epoch 141: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 297s 31ms/step - loss: 0.0076 - accuracy: 0.9711 - val_loss: 0.0520 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 142/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9711
# Epoch 142: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 292s 30ms/step - loss: 0.0074 - accuracy: 0.9711 - val_loss: 0.0491 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 143/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9716
# Epoch 143: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 311s 32ms/step - loss: 0.0077 - accuracy: 0.9716 - val_loss: 0.0529 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 144/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9711
# Epoch 144: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0075 - accuracy: 0.9711 - val_loss: 0.0506 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 145/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9732
# Epoch 145: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 300s 31ms/step - loss: 0.0072 - accuracy: 0.9732 - val_loss: 0.0503 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 146/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9712
# Epoch 146: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0074 - accuracy: 0.9712 - val_loss: 0.0482 - val_accuracy: 0.8945 - lr: 1.0000e-06
# Epoch 147/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9742
# Epoch 147: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0070 - accuracy: 0.9742 - val_loss: 0.0502 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 148/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9738
# Epoch 148: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 292s 30ms/step - loss: 0.0070 - accuracy: 0.9738 - val_loss: 0.0456 - val_accuracy: 0.8881 - lr: 1.0000e-06
# Epoch 149/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9732
# Epoch 149: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 292s 30ms/step - loss: 0.0070 - accuracy: 0.9732 - val_loss: 0.0544 - val_accuracy: 0.8934 - lr: 1.0000e-06
# Epoch 150/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9757
# Epoch 150: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 309s 32ms/step - loss: 0.0068 - accuracy: 0.9757 - val_loss: 0.0511 - val_accuracy: 0.8998 - lr: 1.0000e-06
# Epoch 151/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9749
# Epoch 151: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 313s 32ms/step - loss: 0.0066 - accuracy: 0.9749 - val_loss: 0.0496 - val_accuracy: 0.8998 - lr: 1.0000e-06
# Epoch 152/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9766
# Epoch 152: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 298s 31ms/step - loss: 0.0065 - accuracy: 0.9766 - val_loss: 0.0494 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 153/400
# 9643/9643 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9758
# Epoch 153: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 305s 32ms/step - loss: 0.0066 - accuracy: 0.9758 - val_loss: 0.0521 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 154/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9758
# Epoch 154: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 325s 34ms/step - loss: 0.0065 - accuracy: 0.9758 - val_loss: 0.0531 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 155/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9759
# Epoch 155: val_accuracy did not improve from 0.91151
# 9643/9643 [==============================] - 313s 32ms/step - loss: 0.0064 - accuracy: 0.9759 - val_loss: 0.0502 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 156/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9767
# ...
# Epoch 350: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 302s 31ms/step - loss: 8.6216e-04 - accuracy: 0.9968 - val_loss: 0.0612 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 351/400
# 9643/9643 [==============================] - ETA: 0s - loss: 8.3762e-04 - accuracy: 0.9975
# Epoch 351: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 8.3762e-04 - accuracy: 0.9975 - val_loss: 0.0572 - val_accuracy: 0.9104 - lr: 1.0000e-06
# Epoch 352/400
# 9643/9643 [==============================] - ETA: 0s - loss: 8.9313e-04 - accuracy: 0.9968
# Epoch 352: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 294s 30ms/step - loss: 8.9313e-04 - accuracy: 0.9968 - val_loss: 0.0579 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 353/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.8088e-04 - accuracy: 0.9976
# Epoch 353: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 336s 35ms/step - loss: 7.8088e-04 - accuracy: 0.9976 - val_loss: 0.0583 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 354/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.5452e-04 - accuracy: 0.9975
# Epoch 354: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 322s 33ms/step - loss: 7.5452e-04 - accuracy: 0.9975 - val_loss: 0.0590 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 355/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 8.2882e-04 - accuracy: 0.9975
# Epoch 355: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 337s 35ms/step - loss: 8.2877e-04 - accuracy: 0.9975 - val_loss: 0.0706 - val_accuracy: 0.8699 - lr: 1.0000e-06
# Epoch 356/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.6545e-04 - accuracy: 0.9975
# Epoch 356: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 7.6537e-04 - accuracy: 0.9975 - val_loss: 0.0628 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 357/400
# 9643/9643 [==============================] - ETA: 0s - loss: 8.2891e-04 - accuracy: 0.9972
# Epoch 357: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 322s 33ms/step - loss: 8.2891e-04 - accuracy: 0.9972 - val_loss: 0.0619 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 358/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.9602e-04 - accuracy: 0.9973
# Epoch 358: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 272s 28ms/step - loss: 7.9630e-04 - accuracy: 0.9973 - val_loss: 0.0567 - val_accuracy: 0.9083 - lr: 1.0000e-06
# Epoch 359/400
# 9643/9643 [==============================] - ETA: 0s - loss: 8.8537e-04 - accuracy: 0.9965
# Epoch 359: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 290s 30ms/step - loss: 8.8537e-04 - accuracy: 0.9965 - val_loss: 0.0591 - val_accuracy: 0.8998 - lr: 1.0000e-06
# Epoch 360/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.8123e-04 - accuracy: 0.9970
# Epoch 360: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 273s 28ms/step - loss: 7.8123e-04 - accuracy: 0.9970 - val_loss: 0.0616 - val_accuracy: 0.9072 - lr: 1.0000e-06
# Epoch 361/400
# 9643/9643 [==============================] - ETA: 0s - loss: 8.3409e-04 - accuracy: 0.9967
# Epoch 361: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 318s 33ms/step - loss: 8.3409e-04 - accuracy: 0.9967 - val_loss: 0.0591 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 362/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.8648e-04 - accuracy: 0.9971
# Epoch 362: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 7.8648e-04 - accuracy: 0.9971 - val_loss: 0.0599 - val_accuracy: 0.9072 - lr: 1.0000e-06
# Epoch 363/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.6717e-04 - accuracy: 0.9974
# Epoch 363: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 295s 31ms/step - loss: 7.6709e-04 - accuracy: 0.9974 - val_loss: 0.0606 - val_accuracy: 0.9072 - lr: 1.0000e-06
# Epoch 364/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 8.1187e-04 - accuracy: 0.9975
# Epoch 364: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 309s 32ms/step - loss: 8.1179e-04 - accuracy: 0.9975 - val_loss: 0.0572 - val_accuracy: 0.9009 - lr: 1.0000e-06
# Epoch 365/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 8.5868e-04 - accuracy: 0.9970
# Epoch 365: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 279s 29ms/step - loss: 8.5871e-04 - accuracy: 0.9970 - val_loss: 0.0594 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 366/400
# 9643/9643 [==============================] - ETA: 0s - loss: 9.2855e-04 - accuracy: 0.9968
# Epoch 366: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 317s 33ms/step - loss: 9.2855e-04 - accuracy: 0.9968 - val_loss: 0.0667 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 367/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.5810e-04 - accuracy: 0.9979
# Epoch 367: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 6.5810e-04 - accuracy: 0.9979 - val_loss: 0.0579 - val_accuracy: 0.9104 - lr: 1.0000e-06
# Epoch 368/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 7.0480e-04 - accuracy: 0.9975
# Epoch 368: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 291s 30ms/step - loss: 7.0466e-04 - accuracy: 0.9975 - val_loss: 0.0630 - val_accuracy: 0.9051 - lr: 1.0000e-06
# Epoch 369/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.2705e-04 - accuracy: 0.9976
# Epoch 369: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 294s 31ms/step - loss: 7.2705e-04 - accuracy: 0.9976 - val_loss: 0.0579 - val_accuracy: 0.9136 - lr: 1.0000e-06
# Epoch 370/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.6350e-04 - accuracy: 0.9973
# Epoch 370: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 327s 34ms/step - loss: 7.6350e-04 - accuracy: 0.9973 - val_loss: 0.0587 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 371/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 7.7131e-04 - accuracy: 0.9971
# Epoch 371: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 303s 31ms/step - loss: 7.7115e-04 - accuracy: 0.9971 - val_loss: 0.0616 - val_accuracy: 0.8966 - lr: 1.0000e-06
# Epoch 372/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 6.7077e-04 - accuracy: 0.9976
# Epoch 372: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 366s 38ms/step - loss: 6.7063e-04 - accuracy: 0.9976 - val_loss: 0.0605 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 373/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 7.4804e-04 - accuracy: 0.9975
# Epoch 373: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 287s 30ms/step - loss: 7.4794e-04 - accuracy: 0.9975 - val_loss: 0.0582 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 374/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.4904e-04 - accuracy: 0.9979
# Epoch 374: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 323s 34ms/step - loss: 6.4904e-04 - accuracy: 0.9979 - val_loss: 0.0633 - val_accuracy: 0.9126 - lr: 1.0000e-06
# Epoch 375/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.8100e-04 - accuracy: 0.9975
# Epoch 375: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 294s 30ms/step - loss: 6.8093e-04 - accuracy: 0.9975 - val_loss: 0.0648 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 376/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.2543e-04 - accuracy: 0.9973
# Epoch 376: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 7.2543e-04 - accuracy: 0.9973 - val_loss: 0.0605 - val_accuracy: 0.9104 - lr: 1.0000e-06
# Epoch 377/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.1167e-04 - accuracy: 0.9974
# Epoch 377: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 299s 31ms/step - loss: 7.1160e-04 - accuracy: 0.9974 - val_loss: 0.0652 - val_accuracy: 0.9072 - lr: 1.0000e-06
# Epoch 378/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.0657e-04 - accuracy: 0.9978
# Epoch 378: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 6.0651e-04 - accuracy: 0.9978 - val_loss: 0.0572 - val_accuracy: 0.9158 - lr: 1.0000e-06
# Epoch 379/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.3542e-04 - accuracy: 0.9973
# Epoch 379: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 364s 38ms/step - loss: 7.3536e-04 - accuracy: 0.9973 - val_loss: 0.0630 - val_accuracy: 0.8998 - lr: 1.0000e-06
# Epoch 380/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.7341e-04 - accuracy: 0.9978
# Epoch 380: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 6.7334e-04 - accuracy: 0.9978 - val_loss: 0.0591 - val_accuracy: 0.9051 - lr: 1.0000e-06
# Epoch 381/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.5775e-04 - accuracy: 0.9975
# Epoch 381: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 317s 33ms/step - loss: 7.5775e-04 - accuracy: 0.9975 - val_loss: 0.0564 - val_accuracy: 0.9136 - lr: 1.0000e-06
# Epoch 382/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.8028e-04 - accuracy: 0.9980
# Epoch 382: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 323s 33ms/step - loss: 6.8021e-04 - accuracy: 0.9980 - val_loss: 0.0611 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 383/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.7818e-04 - accuracy: 0.9976
# Epoch 383: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 321s 33ms/step - loss: 6.7811e-04 - accuracy: 0.9976 - val_loss: 0.0625 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 384/400
# 9643/9643 [==============================] - ETA: 0s - loss: 7.3090e-04 - accuracy: 0.9976
# Epoch 384: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 298s 31ms/step - loss: 7.3090e-04 - accuracy: 0.9976 - val_loss: 0.0611 - val_accuracy: 0.9072 - lr: 1.0000e-06
# Epoch 385/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 7.4661e-04 - accuracy: 0.9975
# Epoch 385: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 7.4654e-04 - accuracy: 0.9975 - val_loss: 0.0591 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 386/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.5971e-04 - accuracy: 0.9977
# Epoch 386: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 298s 31ms/step - loss: 6.5965e-04 - accuracy: 0.9977 - val_loss: 0.0788 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 387/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.1988e-04 - accuracy: 0.9981
# Epoch 387: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 300s 31ms/step - loss: 6.1982e-04 - accuracy: 0.9981 - val_loss: 0.0576 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 388/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.6871e-04 - accuracy: 0.9976
# Epoch 388: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 376s 39ms/step - loss: 6.6864e-04 - accuracy: 0.9976 - val_loss: 0.0758 - val_accuracy: 0.8795 - lr: 1.0000e-06
# Epoch 389/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.2640e-04 - accuracy: 0.9979
# Epoch 389: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 372s 39ms/step - loss: 6.2633e-04 - accuracy: 0.9979 - val_loss: 0.0648 - val_accuracy: 0.9030 - lr: 1.0000e-06
# Epoch 390/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.6121e-04 - accuracy: 0.9978
# Epoch 390: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 285s 30ms/step - loss: 6.6114e-04 - accuracy: 0.9978 - val_loss: 0.0604 - val_accuracy: 0.9104 - lr: 1.0000e-06
# Epoch 391/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.9384e-04 - accuracy: 0.9976
# Epoch 391: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 327s 34ms/step - loss: 6.9376e-04 - accuracy: 0.9976 - val_loss: 0.0639 - val_accuracy: 0.8987 - lr: 1.0000e-06
# Epoch 392/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.1743e-04 - accuracy: 0.9980
# Epoch 392: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 335s 35ms/step - loss: 6.1743e-04 - accuracy: 0.9980 - val_loss: 0.0647 - val_accuracy: 0.8977 - lr: 1.0000e-06
# Epoch 393/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.0600e-04 - accuracy: 0.9976
# Epoch 393: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 301s 31ms/step - loss: 6.0600e-04 - accuracy: 0.9976 - val_loss: 0.0636 - val_accuracy: 0.9019 - lr: 1.0000e-06
# Epoch 394/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.2469e-04 - accuracy: 0.9980
# Epoch 394: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 321s 33ms/step - loss: 6.2462e-04 - accuracy: 0.9980 - val_loss: 0.0607 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 395/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.8126e-04 - accuracy: 0.9975
# Epoch 395: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 296s 31ms/step - loss: 6.8126e-04 - accuracy: 0.9975 - val_loss: 0.0727 - val_accuracy: 0.8913 - lr: 1.0000e-06
# Epoch 396/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.6154e-04 - accuracy: 0.9979
# Epoch 396: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 339s 35ms/step - loss: 6.6154e-04 - accuracy: 0.9979 - val_loss: 0.0593 - val_accuracy: 0.9136 - lr: 1.0000e-06
# Epoch 397/400
# 9641/9643 [============================>.] - ETA: 0s - loss: 6.0037e-04 - accuracy: 0.9979
# Epoch 397: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 297s 31ms/step - loss: 6.0027e-04 - accuracy: 0.9979 - val_loss: 0.0675 - val_accuracy: 0.9041 - lr: 1.0000e-06
# Epoch 398/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.2234e-04 - accuracy: 0.9977
# Epoch 398: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 322s 33ms/step - loss: 6.2227e-04 - accuracy: 0.9977 - val_loss: 0.0642 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 399/400
# 9643/9643 [==============================] - ETA: 0s - loss: 6.3077e-04 - accuracy: 0.9977
# Epoch 399: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 322s 33ms/step - loss: 6.3077e-04 - accuracy: 0.9977 - val_loss: 0.0693 - val_accuracy: 0.9094 - lr: 1.0000e-06
# Epoch 400/400
# 9642/9643 [============================>.] - ETA: 0s - loss: 6.6113e-04 - accuracy: 0.9977
# Epoch 400: val_accuracy did not improve from 0.92111
# 9643/9643 [==============================] - 320s 33ms/step - loss: 6.6106e-04 - accuracy: 0.9977 - val_loss: 0.0643 - val_accuracy: 0.8966 - lr: 1.0000e-06

# %%
#model.load_weights('Skin_attent_weights_acc_att_wave_14_focal.h5')

# %%
model.save_weights('modelFocal')

# %%
predictions = model.predict(test_batches, steps=len(test_batches), verbose=0)
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image 
y_true = test_batches.classes
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("Classification Report:")
print(report)

# %% [markdown]
# # <a id='Efficient_net'>Efficient-net</a>
# #### [Return Contents](#intro)

# %%
#! /opt/conda/bin/python3.7 -m pip install -q --upgrade pip
#! pip install -q efficientnet

# %%
import efficientnet.tfkeras as efn

# %%
def get_model():
    
    ''' This function gets the layers inclunding efficientnet ones. '''
    
    model_input = tf.keras.Input(shape=(224,224, 3),
                                 name='img_input')

    dummy = tf.keras.layers.Lambda(lambda x: x)(model_input)



    x = efn.EfficientNetB7(include_top=False,
                           weights='noisy-student',
                           input_shape=(224,224, 3),
                           pooling='avg')(dummy)
    x = tf.keras.layers.Dense(7, activation='softmax')(x)
    
    """
    x = efn.EfficientNetB4(include_top=False,
                           weights='noisy-student',
                           input_shape=(224,224, 3),
                           pooling='avg')(dummy)
    x = tf.keras.layers.Dense(7, activation='softmax')(x)
    outputs.append(x)
    """
    """
    x = efn.EfficientNetB5(include_top=False,
                           weights='noisy-student',
                           input_shape=(224,224, 3),
                           pooling='avg')(dummy)
    x = tf.keras.layers.Dense(7, activation='softmax')(x)
    outputs.append(x)
    """

    model = tf.keras.Model(model_input, x, name='aNetwork')
    model.summary()
    return model

# %%
with strategy.scope():
    base = efn.EfficientNetB7(include_top=False,
                               weights='noisy-student',
                               input_shape=(224,224, 3),
                               pooling='avg', classes=7)

# %%
with strategy.scope():
    efficient = get_model()
# Out:
# Model: "aNetwork"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img_input (InputLayer)      [(None, 224, 224, 3)]     0
#
#  lambda (Lambda)             (None, 224, 224, 3)       0
#
#  efficientnet-b7 (Functional  (None, 2560)             64097680
#  )
#
#  dense_2 (Dense)             (None, 7)                 17927
#
# =================================================================
# Total params: 64,115,607
# Trainable params: 63,804,887
# Non-trainable params: 310,720
# _________________________________________________________________

# %%
def compileNewModel():
    
    ''' Configuring the model with losses and metrics. '''    
    
    with strategy.scope():
        model = efficient

    with strategy.scope():
        model.compile(optimizer='adam', loss='categorical_crossentropy', 
                      metrics=['accuracy'])
        #tf.keras.metrics.AUC(name='auc')
    return model

def getLearnRateCallback(cfg):
    
    ''' Using callbacks for learning rate adjustments. '''
    
    lr_start = cfg['lr_start']
    lr_max = cfg['lr_max'] * strategy.num_replicas_in_sync * cfg['batch_size']
    lr_min = cfg['lr_min']
    lr_rampup = cfg['lr_rampup']
    lr_sustain = cfg['lr_sustain']
    lr_decay = cfg['lr_decay']

    def lrfn(epoch):
        if epoch < lr_rampup:
            lr = (lr_max - lr_start) / lr_rampup * epoch + lr_start
        elif epoch < lr_rampup + lr_sustain:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_rampup -
                                                lr_sustain) + lr_min
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback


def learnModel(model, ds_train, cfg, ds_val):
    
    ''' Fitting things together for training '''
    
    filepath1 = "Efficient_att_ens.h5"
    checkpoint = ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)
    callbacks = [getLearnRateCallback(cfg), checkpoint]

    history = model.fit(ds_train,
                        validation_data=ds_val,
                        verbose=True,
                        epochs=10,
                        callbacks=callbacks)

    return history

# %%
#efficient net bou7dou i have to save it tooo.. # hada wavelet with global dolg i have to save it (la 2eme fois je dois uploader les meilleurs poids avant enregistremnt)
model1 = compileNewModel()
history1 = learnModel(model1, train_batches, cfg, valid_batches)
# Out:
# Epoch 1/10
# 9643/9643 [==============================] - ETA: 0s - loss: 1.4616 - accuracy: 0.4439
# Epoch 1: val_accuracy improved from -inf to 0.81557, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2433s 241ms/step - loss: 1.4616 - accuracy: 0.4439 - val_loss: 0.6177 - val_accuracy: 0.8156 - lr: 5.0000e-06
# Epoch 2/10
# 9643/9643 [==============================] - ETA: 0s - loss: 1.0844 - accuracy: 0.6005
# Epoch 2: val_accuracy improved from 0.81557 to 0.83049, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2389s 248ms/step - loss: 1.0844 - accuracy: 0.6005 - val_loss: 0.5259 - val_accuracy: 0.8305 - lr: 5.0000e-06
# Epoch 3/10
# 9643/9643 [==============================] - ETA: 0s - loss: 0.9432 - accuracy: 0.6538
# Epoch 3: val_accuracy improved from 0.83049 to 0.84755, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2290s 237ms/step - loss: 0.9432 - accuracy: 0.6538 - val_loss: 0.4573 - val_accuracy: 0.8475 - lr: 5.0000e-06
# Epoch 4/10
# 9643/9643 [==============================] - ETA: 0s - loss: 0.8449 - accuracy: 0.6933
# Epoch 4: val_accuracy improved from 0.84755 to 0.85288, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2411s 250ms/step - loss: 0.8449 - accuracy: 0.6933 - val_loss: 0.3982 - val_accuracy: 0.8529 - lr: 5.0000e-06
# Epoch 5/10
# 9643/9643 [==============================] - ETA: 0s - loss: 0.7685 - accuracy: 0.7182
# Epoch 5: val_accuracy improved from 0.85288 to 0.86887, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2345s 243ms/step - loss: 0.7685 - accuracy: 0.7182 - val_loss: 0.3659 - val_accuracy: 0.8689 - lr: 5.0000e-06
# Epoch 6/10
# 9643/9643 [==============================] - ETA: 0s - loss: 0.7056 - accuracy: 0.7428
# Epoch 6: val_accuracy improved from 0.86887 to 0.87953, saving model to Efficient_att_ens.h5
# 9643/9643 [==============================] - 2313s 240ms/step - loss: 0.7056 - accuracy: 0.7428 - val_loss: 0.3348 - val_accuracy: 0.8795 - lr: 5.0000e-06
# Epoch 7/10
#  932/9643 [=>............................] - ETA: 36:12 - loss: 0.6856 - accuracy: 0.7559

# %%
#model1.load_weights('Efficient_att_ens.h5')

# %% [markdown]
# # <a id='Ensemble_learning'>Ensemble learning</a>
# #### [Return Contents](#intro)

# %%
from sklearn.utils import class_weight
#y_train_w = np.array(y_train)
#class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)

# %%
model_input = keras.Input((224,224,3))
def ensemble(models, model_input):
    outputs = [model(model_input) for model in models]
    y = keras.layers.Average()(outputs)
    model = Model(model_input, y, name='ensemble')
    return model
def compileNewModel():
    
    ''' Configuring the model with losses and metrics. '''    
    
    with strategy.scope():
        model = ensemble([wavelet, efficient], model_input)

    with strategy.scope():
        model.compile(optimizer='adam', loss='categorical_crossentropy', 
                      metrics=['accuracy'])
        #tf.keras.metrics.AUC(name='auc')
    return model

def getLearnRateCallback(cfg):
    
    ''' Using callbacks for learning rate adjustments. '''
    
    lr_start = cfg['lr_start']
    lr_max = cfg['lr_max'] * strategy.num_replicas_in_sync * cfg['batch_size']
    lr_min = cfg['lr_min']
    lr_rampup = cfg['lr_rampup']
    lr_sustain = cfg['lr_sustain']
    lr_decay = cfg['lr_decay']

    def lrfn(epoch):
        if epoch < lr_rampup:
            lr = (lr_max - lr_start) / lr_rampup * epoch + lr_start
        elif epoch < lr_rampup + lr_sustain:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_rampup -
                                                lr_sustain) + lr_min
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback


def learnModel(model, ds_train, cfg, ds_val):
    
    ''' Fitting things together for training '''
    
    filepath1 = "Ensemble_att_ens.h5"
    checkpoint = ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)
    callbacks = [getLearnRateCallback(cfg), checkpoint]

    history = model.fit(ds_train,
                        validation_data=ds_val,
                        verbose=True,
                        epochs=10,
                        callbacks=callbacks)

    return history

# %%
model2 = compileNewModel()
history2 = learnModel(model2, train_batches, cfg, valid_batches)

# %%
import seaborn as sns
def plot_training_curves(history, ):
    
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])

    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    epochs = range(len(history.history['loss']))

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='o')
    ax1.plot(epochs, val_loss, label='val_loss', marker='o')
    
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)

    ax1.set_title('Loss (Lower Means Better)', fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=12)
    ax1.legend()

    # Plot accuracy
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='o')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='o')
    
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)

    ax2.set_title('Accuracy (Higher Means Better)', fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=12)
    ax2.legend();
    
    sns.despine();

# %%
def info_layers(model ):
    # вывод информации по слоям модели в процессе тюнинга
    
    print("Number of layers in the model:", len(model.layers))
    print("Number of trainable_variables layers in the model:", len(model.trainable_variables))
    #print("Number of layers in the base model: ", len(base_model.layers))
    #print("Number of variables layers in the base model: ", len(base_model.trainable_variables))
    #print("Layers in the model:")
    #for layer in model.layers:
     #   print(layer, layer.trainable)

def graph(history):
    # построние графиков изменения метрики и функции потерь в процессе обучения по эпохам
    
    plt.figure(figsize=(8, 4))
    plt.plot(history.history['accuracy'], 'b*-', label="training acc")
    plt.plot(history.history['val_accuracy'], 'r*-', label="validation acc")
    plt.grid()
    plt.title("train_acc vs val_acc")
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

    plt.figure(figsize=(8, 4))
    plt.plot(history.history['loss'], 'b*-', label="training loss")
    plt.plot(history.history['val_loss'], 'r*-', label="validation loss")
    plt.grid()
    plt.title("Training and validation loss")
    plt.ylabel("Loss")
    plt.xlabel("Epochs")
    plt.legend()
    plt.show()

# %%
plot_training_curves(history)

# %%
graph(history)

# %%
plot_training_curves(history1)

# %%
graph(history1)

# %%
plot_training_curves(history2)

# %%
graph(history2)

# %%
print(info_layers(model))
print('---------------------------------------------------------------------------------------')
print(info_layers(dolg_net.layers[0]))
print('---------------------------------------------------------------------------------------')
print(info_layers(dolg_net))

# %%
print(info_layers(model1))
print('---------------------------------------------------------------------------------------')
print(info_layers(model1.layers[2]))

# %% [markdown]
# model2.summary()

# %%
print(info_layers(model2))
print('---------------------------------------------------------------------------------------')
print(info_layers(model2.layers[1]))
print('---------------------------------------------------------------------------------------')
print(info_layers(model2.layers[2]))

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()



# argmax returns the index of the max value in a row bl weights ou transfer learning bla augmentation
#cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
# Define the labels of the class indices. These need to match the 
# order shown above.
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']

# %%
def metrics(model):  
    predictions = model.predict(test_batches, steps=len(test_batches), verbose=0)
    #geting predictions on test dataset
    y_pred = np.argmax(predictions, axis=1)
    targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
    #getting the true labels per image 
    y_true = test_batches.classes
    #getting the predicted labels per image 
    y_prob=predictions
    from tensorflow.keras.utils import to_categorical
    y_test = to_categorical(y_true)

    # Creating classification report 
    report = classification_report(y_true, y_pred, target_names=targetnames)

    print("Classification Report:")
    print(report)

    print('---------------------------------------------------------------------------------------')
    print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
    print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
    print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
    print("weighted Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='weighted')))

    print('---------------------------------------------------------------------------------------')
    print("Precision: "+ str(precision_score(y_true, y_pred, average='macro')))
    print("Recall: "+ str(recall_score(y_true, y_pred, average='macro')))
    print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
    print("Macro Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='macro')))
    
    print('---------------------------------------------------------------------------------------')
    print("Precision: "+ str(precision_score(y_true, y_pred, average='micro')))
    print("Recall: "+ str(recall_score(y_true, y_pred, average='micro')))
    print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
    tpr={}
    fpr={}
    roc_auc={}
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_prob.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    print("Micro Roc score: " + str(roc_auc["micro"]))

    print('---------------------------------------------------------------------------------------')
    fpr = {}
    tpr = {}
    roc_auc = {}
    for i in range(7):
        r = roc_auc_score(y_test[:, i], y_prob[:, i])
        print("The ROC AUC score of "+targetnames[i]+" is:" +str(r))

    # Compute ROC curve and ROC area for each class
    fpr = {}
    tpr = {}
    roc_auc = dict()
    for i in range(7):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_prob[:, i], drop_intermediate=False)
        roc_auc[i] = auc(fpr[i], tpr[i])

    plt.plot(fpr[0], tpr[0],'v-',label='akiec: ROC curve of (area = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1],'c',label='bcc: ROC curve of (area = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2],'b',label='bkl: ROC curve of (area = %0.2f)' % roc_auc[2])
    plt.plot(fpr[3], tpr[3],'g',label='df: ROC curve of (area = %0.2f)' % roc_auc[3])
    plt.plot(fpr[4], tpr[4],'y',label='mel: ROC curve of (area = %0.2f)' % roc_auc[4])
    plt.plot(fpr[5], tpr[5],'o-',label='nv: ROC curve of (area = %0.2f)' % roc_auc[5])
    plt.plot(fpr[6], tpr[6],'r',label='vasc: ROC curve of (area = %0.2f)' % roc_auc[6])

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.1, 1.1])
    plt.ylim([-0.1, 1.1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic of %s'%targetnames[i])
    plt.legend(loc="lower right")
    plt.show()
    return predictions

# %%
import itertools
test_labels = test_batches.classes
# argmax returns the index of the max value in a row bl weights ou transfer learning bla augmentation
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
# Define the labels of the class indices. These need to match the 
# order shown above.
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']

plot_confusion_matrix(cm, cm_plot_labels,normalize=True, title='Confusion Matrix')

# %%
predictions = metrics(model1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import cv2
from  matplotlib import pyplot as plt
import numpy as np
from numpy import expand_dims
file_path= r"D:\Doctorat\test\0\ISIC_0025513.jpg"
test_image = cv2.imread(file_path)
test_image = cv2.resize(test_image, (224,224))
test_image = test_image.astype(np.float32) / 255.0
#plt.imshow(test_image)
#test_image = np.expand_dims(test_image,axis=0)
display(Image(file_path))

# %%
# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0
    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    return image, width, height

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from numpy import expand_dims
from matplotlib import pyplot
from matplotlib.patches import Rectangle
# define the expected input shape for the model
input_w, input_h = 224, 224
# define our new photo
# load and prepare image
image, image_w, image_h = load_image_pixels(file_path, (input_w, input_h))


def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model2.layers[2].layers[2].inputs], [model2.layers[2].layers[2].get_layer(last_conv_layer_name).output, model2.layers[2].layers[2].output]
    )
    #[model.layers[1].layers[2].inputs], [model.layers[1].layers[2].get_layer(last_conv_layer_name).output, model.layers[1].layers[2].output]
    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy(), heatmap


labels_dict = {'akiec':0,'bcc':1,'bkl':2,'df':3,'mel':4
               ,'nv':5,'vasc':6}

classe = {v: k for k, v in labels_dict.items()}

model2.layers[2].layers[2].get_layer('top_conv')

preprocess_input = keras.applications.densenet.preprocess_input
decode_predictions = keras.applications.densenet.decode_predictions

img_size = (224, 224)
# Prepare image
img_array = preprocess_input(get_img_array(file_path, size=img_size))

# Make model
#model = model()

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)

preds= preds.tolist()
max_value = max(preds[0])
max_index = preds[0].index(max_value)
print(preds)
print("Predicted:", classe[max_index])


# Generate class activation heatmap
heatmap, _ = make_gradcam_heatmap(img_array, model, 'top_conv')

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
heatmapshow = cv2.normalize(heatmap, None, alpha=0, beta=155, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
heatmapshow = cv2.applyColorMap(heatmapshow, cv2.COLORMAP_JET)

plt.imshow(heatmapshow)

# %%
from matplotlib import pyplot
from cv2 import cv2
from matplotlib import patches
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)


    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((224,224)) #(img.shape[1], img.shape[0])
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    
    heatmapshow = cv2.normalize(jet_heatmap, None, alpha=0, beta=155, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    heatmapshow = cv2.applyColorMap(heatmapshow, cv2.COLORMAP_JET)
    gray = cv2.cvtColor(heatmapshow, cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
    contours,hierarchy = cv2.findContours(thresh, 1, 2)

    for item in range(len(contours)):
        cnt = contours[item]
        img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224,224))
        image1 = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
        fig, ax = plt.subplots(figsize=(15,15))
        ax.imshow(img)
        if len(cnt)>20:
            #print(len(cnt))
            x,y,w,h = cv2.boundingRect(cnt) # x, y is the top left corner, and w, h are the width and height respectively
            poly_coords = [cnt] # polygon coordinates are based on contours
            """
            x = int(x*self.scale_list[0]) # rescaling the boundary box based on user input
            y = int(y*self.scale_list[1])
            w = int(w*self.scale_list[2])
            h = int(h*self.scale_list[3])"""
            rect = patches.Rectangle( (x, y), w,  h, linewidth=2, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
            label = "%s (%.3f" % (classe[max_index], max_value) + "%)"
            pyplot.text(x,y-10, label, color='red',fontsize= "xx-large")
 
    
    
    

    
    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    
    #plt.imshow(heatmapshow)
    
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))



save_and_display_gradcam(file_path, heatmap)

# %%
#second ensemble learning try just to compare
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)
    img = cv2.resize(img, (224,224))

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((224,224)) #(img.shape[1], img.shape[0])
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))
    return superimposed_img


simpsimg = save_and_display_gradcam(file_path, heatmap)

# %%
plt.figure(figsize=(30,30))
plt.subplot(1,4,1),    plt.imshow(img_array[0]), plt.title(classe[max_index])
plt.subplot(1,4,2),    plt.imshow(heatmap)
plt.subplot(1,4,3),    plt.imshow(heatmapshow)
plt.subplot(1,4,4),    plt.imshow(simpsimg)

# %%
import cv2
from PIL import Image
from sklearn import preprocessing
import tensorflow as tf

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.layers[1].layers[2].inputs], [model.layers[1].layers[2].get_layer(last_conv_layer_name).output, model.layers[1].layers[2].output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()
def normalization(image):
    return (image - image.min())/(image.max() - image.min())

def gray_to_redblue(image):
    R,G,B = image[:,:,0], image[:,:,1], image[:,:,2]
    #grey = sum(pixel) // len(pixel)
    redvalue = 1 - R  # "darkness"
    bluevalue = B  # "brightness"
    image[:,:,0] = B
    image[:,:,1] = 0
    image[:,:,2] = 1-R
    return image# + alpha

def generate_CAM(image,layer):
    img_array = np.reshape(image,(1,224,224,3))
    preds = model.predict(img_array)
    H5py_cam = make_gradcam_heatmap(img_array,model,layer)
    print(H5py_cam.shape)
    heatmap = cv2.resize(H5py_cam,(img_array.shape[1],img_array.shape[2]))
    img_map = np.reshape(img_array,(224,224,3))
    heatmap = normalization(heatmap)
    img_map = normalization(img_map)
    heatmap = cv2.cvtColor(heatmap,cv2.COLOR_GRAY2RGB)
    #img_map = cv2.cvtColor(img_map,cv2.COLOR_GRAY2RGB)
    #heatmap = gray_to_redblue(heatmap)
    #heatmap = cv2.cvtColor(heatmap,cv2.COLOR_GRAY2RGB)
    print(heatmap.shape)
    print(img_map.shape)
    combination = heatmap * 0.8 + img_map * 1

    plt.imshow(combination)
    plt.show()
    
    pylab.imshow(img_map, cmap=pylab.cm.gray)  
    pylab.show()
    pylab.imshow(heatmap, cmap=pylab.cm.jet)  
    pylab.show()
    
#generate_CAM(ct_slices[378],'max_pooling2d_1')
import matplotlib.cm as cm
def superimposed_img(image, heatmap):
    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)
    img = keras.preprocessing.image.array_to_img(image)
    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # We create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((image_size, image_size))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * 0.4 + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    return img, superimposed_img

# %%
feature_map_model = tf.keras.models.Model(
        [model2.layers[2].layers[2].inputs], [model2.layers[2].layers[2].get_layer('top_conv').output, model2.layers[2].layers[2].output]
    )

# %%
#second ensemble learning try just to compare
import keras
import random
plt.figure(figsize=(30,30))
for j in range(5):
    rand = random.randint(0, 7)
    test_image = cv2.resize(test_batches[rand][0][0], (224,224),interpolation=cv2.INTER_NEAREST)
    test_image = np.expand_dims(test_image,axis=0)
    test_image = np.maximum(test_image, 0) / np.max(test_image)
    img = keras.preprocessing.image.array_to_img(test_image[0])
    with tf.GradientTape() as tape:
            # Compute activations of the last conv layer and make the tape watch it
            #last_conv_layer_output1 = feature_map_model1(test_image)
            last_conv_layer_output, preds = feature_map_model(test_image)
            tape.watch(last_conv_layer_output)
            top_pred_index = tf.argmax(preds[0])
            top_class_channel = preds[:, top_pred_index]
    grads = tape.gradient(top_class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]
    heatmap = np.mean(last_conv_layer_output, axis=-1)

        # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    im, s_img = superimposed_img(test_image[0] , heatmap)
    
    d = j * 3
    plt.subplot(5,3,d+1),    plt.imshow(im)
    plt.subplot(5,3,d+2),    plt.imshow(heatmap)
    plt.subplot(5,3,d+3),    plt.imshow(s_img)
plt.show()

# %% [markdown]
# # <a id='Gradcam'>Grad-CAM Bbox</a>
# #### [Return Contents](#intro)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import cv2
from  matplotlib import pyplot as plt
import numpy as np
from numpy import expand_dims
file_path= r"D:\Doctorat\test\0\ISIC_0025513.jpg"
test_image = cv2.imread(file_path)
test_image = cv2.resize(test_image, (224,224))
test_image = test_image.astype(np.float32) / 255.0
#plt.imshow(test_image)
#test_image = np.expand_dims(test_image,axis=0)
display(Image(file_path))

# %%
# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0
    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    return image, width, height

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from numpy import expand_dims
from matplotlib import pyplot
from matplotlib.patches import Rectangle
# define the expected input shape for the model
input_w, input_h = 224, 224
# define our new photo
# load and prepare image
image, image_w, image_h = load_image_pixels(file_path, (input_w, input_h))

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.layers[2].layers[2].inputs], [model.layers[2].layers[2].get_layer(last_conv_layer_name).output, model.layers[2].layers[2].output]
    )
    #[model.layers[1].layers[2].inputs], [model.layers[1].layers[2].get_layer(last_conv_layer_name).output, model.layers[1].layers[2].output]
    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy(), heatmap

# %%
labels_dict = {'akiec':0,'bcc':1,'bkl':2,'df':3,'mel':4
               ,'nv':5,'vasc':6}

# %%
classe = {v: k for k, v in labels_dict.items()}

# %%
model.layers[2].layers[2].get_layer('top_conv')

# %%
preprocess_input = keras.applications.densenet.preprocess_input
decode_predictions = keras.applications.densenet.decode_predictions

img_size = (224, 224)
# Prepare image
img_array = preprocess_input(get_img_array(file_path, size=img_size))

# Make model
#model = model()

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)

preds= preds.tolist()
max_value = max(preds[0])
max_index = preds[0].index(max_value)
print(preds)
print("Predicted:", classe[max_index])


# Generate class activation heatmap
heatmap, _ = make_gradcam_heatmap(img_array, model, 'top_conv')

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
heatmapshow = cv2.normalize(heatmap, None, alpha=0, beta=155, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
heatmapshow = cv2.applyColorMap(heatmapshow, cv2.COLORMAP_JET)

# %%
plt.imshow(heatmapshow)

# %%
from matplotlib import pyplot
from cv2 import cv2
from matplotlib import patches
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)


    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((224,224)) #(img.shape[1], img.shape[0])
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    
    heatmapshow = cv2.normalize(jet_heatmap, None, alpha=0, beta=155, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    heatmapshow = cv2.applyColorMap(heatmapshow, cv2.COLORMAP_JET)
    gray = cv2.cvtColor(heatmapshow, cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
    contours,hierarchy = cv2.findContours(thresh, 1, 2)

    for item in range(len(contours)):
        cnt = contours[item]
        img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224,224))
        image1 = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
        fig, ax = plt.subplots(figsize=(15,15))
        ax.imshow(img)
        if len(cnt)>20:
            #print(len(cnt))
            x,y,w,h = cv2.boundingRect(cnt) # x, y is the top left corner, and w, h are the width and height respectively
            poly_coords = [cnt] # polygon coordinates are based on contours
            """
            x = int(x*self.scale_list[0]) # rescaling the boundary box based on user input
            y = int(y*self.scale_list[1])
            w = int(w*self.scale_list[2])
            h = int(h*self.scale_list[3])"""
            rect = patches.Rectangle( (x, y), w,  h, linewidth=2, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
            label = "%s (%.3f" % (classe[max_index], max_value) + "%)"
            pyplot.text(x,y-10, label, color='red',fontsize= "xx-large")
 
    
    
    

    
    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    
    #plt.imshow(heatmapshow)
    
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))



save_and_display_gradcam(file_path, heatmap)

# %%
#second ensemble learning try just to compare
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)
    img = cv2.resize(img, (224,224))

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((224,224)) #(img.shape[1], img.shape[0])
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))
    return superimposed_img


simpsimg = save_and_display_gradcam(file_path, heatmap)

# %%
plt.figure(figsize=(30,30))
plt.subplot(1,4,1),    plt.imshow(img_array[0]), plt.title(classe[max_index])
plt.subplot(1,4,2),    plt.imshow(heatmap)
plt.subplot(1,4,3),    plt.imshow(heatmapshow)
plt.subplot(1,4,4),    plt.imshow(simpsimg)

# %% [markdown]
# # <a id='Gradcam'>Grad-CAM</a>

# %%
model.load_weights('Skin_attent_weights_acc_att_ens.h5')

# %%
#ma3reftch 3lach mni 3awdt telecharjit lweights of the model tbeddel ou well ki3ti ghi 92%
model.save('ensemble_92.model')

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()



# argmax returns the index of the max value in a row bl weights ou transfer learning bla augmentation
#cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
# Define the labels of the class indices. These need to match the 
# order shown above.
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']

# %%
predictions = model.predict(test_batches, steps=len(test_batches), verbose=0)

# %%
import itertools
test_labels = test_batches.classes
# argmax returns the index of the max value in a row bl weights ou transfer learning bla augmentation
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
# Define the labels of the class indices. These need to match the 
# order shown above.
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']

plot_confusion_matrix(cm, cm_plot_labels,normalize=True, title='Confusion Matrix')

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.layers[1].layers[2].inputs], [model.layers[1].layers[2].get_layer(last_conv_layer_name).output, model.layers[1].layers[2].output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
def normalization(image):
    return (image - image.min())/(image.max() - image.min())

def gray_to_redblue(image):
    R,G,B = image[:,:,0], image[:,:,1], image[:,:,2]
    #grey = sum(pixel) // len(pixel)
    redvalue = 1 - R  # "darkness"
    bluevalue = B  # "brightness"
    image[:,:,0] = B
    image[:,:,1] = 0
    image[:,:,2] = 1-R
    return image# + alpha

# %%
import cv2
from PIL import Image
from sklearn import preprocessing
import tensorflow as tf

def generate_CAM(image,layer):
    img_array = np.reshape(image,(1,224,224,3))
    preds = model.predict(img_array)
    H5py_cam = make_gradcam_heatmap(img_array,model,layer)
    print(H5py_cam.shape)
    heatmap = cv2.resize(H5py_cam,(img_array.shape[1],img_array.shape[2]))
    img_map = np.reshape(img_array,(224,224,3))
    heatmap = normalization(heatmap)
    img_map = normalization(img_map)
    heatmap = cv2.cvtColor(heatmap,cv2.COLOR_GRAY2RGB)
    #img_map = cv2.cvtColor(img_map,cv2.COLOR_GRAY2RGB)
    #heatmap = gray_to_redblue(heatmap)
    #heatmap = cv2.cvtColor(heatmap,cv2.COLOR_GRAY2RGB)
    print(heatmap.shape)
    print(img_map.shape)
    combination = heatmap * 0.8 + img_map * 1

    plt.imshow(combination)
    plt.show()
    
    pylab.imshow(img_map, cmap=pylab.cm.gray)  
    pylab.show()
    pylab.imshow(heatmap, cmap=pylab.cm.jet)  
    pylab.show()
    
#generate_CAM(ct_slices[378],'max_pooling2d_1')

# %%
import matplotlib.cm as cm
def superimposed_img(image, heatmap):
    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)
    img = keras.preprocessing.image.array_to_img(image)
    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # We create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((image_size, image_size))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * 0.4 + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    return img, superimposed_img

# %%
feature_map_model = tf.keras.models.Model(
        [model.layers[2].layers[2].inputs], [model.layers[2].layers[2].get_layer('top_conv').output, model.layers[2].layers[2].output]
    )

# %%
#second ensemble learning try just to compare
import keras
import random
plt.figure(figsize=(30,30))
for j in range(5):
    rand = random.randint(0, 7)
    test_image = cv2.resize(test_batches[rand][0][0], (224,224),interpolation=cv2.INTER_NEAREST)
    test_image = np.expand_dims(test_image,axis=0)
    test_image = np.maximum(test_image, 0) / np.max(test_image)
    img = keras.preprocessing.image.array_to_img(test_image[0])
    with tf.GradientTape() as tape:
            # Compute activations of the last conv layer and make the tape watch it
            #last_conv_layer_output1 = feature_map_model1(test_image)
            last_conv_layer_output, preds = feature_map_model(test_image)
            tape.watch(last_conv_layer_output)
            top_pred_index = tf.argmax(preds[0])
            top_class_channel = preds[:, top_pred_index]
    grads = tape.gradient(top_class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]
    heatmap = np.mean(last_conv_layer_output, axis=-1)

        # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    im, s_img = superimposed_img(test_image[0] , heatmap)
    
    d = j * 3
    plt.subplot(5,3,d+1),    plt.imshow(im)
    plt.subplot(5,3,d+2),    plt.imshow(heatmap)
    plt.subplot(5,3,d+3),    plt.imshow(s_img)
plt.show()

# %%
datagen = ImageDataGenerator(#preprocessing_function=custom_augmentation,
                             preprocessing_function=tf.keras.applications.densenet.preprocess_input,
                            #horizontal_flip = True,
                            #vertical_flip=True
)


train_batches = datagen.flow_from_directory(r'D:\Doctorat\test',
                                            target_size=(image_size,image_size),
                                            batch_size=train_batch_size,)
                                           #subset='training')

# %%
image, label = next(train_batches)
plt.imshow(image[0])

# %%
"""
image, label = next(train_batches)
plt.imshow(image[0])
i = model.predict(np.expand_dims(image[0],axis=0))
"""
i = model.predict(test_image)
print(i)

pred_lable = np.where(i[0] == max(i[0]))

if(pred_lable[0]==0):
    print("akiec")
elif(pred_lable[0]==1):
    print("bcc")
elif(pred_lable[0]==2):
    print("bkl")
elif(pred_lable[0]==3):
    print("df")
elif(pred_lable[0]==4):
    print("Melanoma")
elif(pred_lable[0]==5):
    print("nv")
elif(pred_lable[0]==6):
    print("vasc")

from IPython.display import Image
Image(filename=file_path,
    width=256,
    height=256,)

# %% [markdown]
# # <a id='metrics'>Result Metrics</a>
# #### [Return Contents](#intro)

# %%
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image 
y_true = test_batches.classes
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("Classification Report:")
print(report)

# %%
#second ensemble learning try just to compare
print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("weighted Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='weighted')))

# %%
#second ensemble learning try just to compare
print("Precision: "+ str(precision_score(y_true, y_pred, average='macro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='macro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("Macro Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='macro')))

# %%
#second ensemble learning try just to compare
print("Precision: "+ str(precision_score(y_true, y_pred, average='micro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='micro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
tpr={}
fpr={}
roc_auc={}
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
print("Micro Roc score: " + str(roc_auc["micro"]))

# %%
#second ensemble learning try just to compare
fpr = {}
tpr = {}
roc_auc = {}
for i in range(7):
    r = roc_auc_score(y_test[:, i], y_prob[:, i])
    print("The ROC AUC score of "+targetnames[i]+" is:" +str(r))

# %%
#second ensemble learning try just to compare
# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_prob[:, i], drop_intermediate=False)
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
#second ensemble learning try just to compare
plt.plot(fpr[0], tpr[0],'v-',label='akiec: ROC curve of (area = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1],'c',label='bcc: ROC curve of (area = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2],'b',label='bkl: ROC curve of (area = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3],'g',label='df: ROC curve of (area = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4],'y',label='mel: ROC curve of (area = %0.2f)' % roc_auc[4])
plt.plot(fpr[5], tpr[5],'o-',label='nv: ROC curve of (area = %0.2f)' % roc_auc[5])
plt.plot(fpr[6], tpr[6],'r',label='vasc: ROC curve of (area = %0.2f)' % roc_auc[6])

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of %s'%targetnames[i])
plt.legend(loc="lower right")
plt.show()

# %%
class_weights = {   
                    0: 1.0,  # akiec
                    1: 1.0,  # bcc
                    2: 1.0,  # bkl
                    3: 1.0,  # df
                    4: 5.0,  # mel
                    5: 1.0,  # nv
                    6: 1.0,  # vasc
                }
def learnModel(model, ds_train, cfg, ds_val):
    
    ''' Fitting things together for training '''
    
    filepath1 = "Skin_attent_weights_acc_att_ens2.h5"
    checkpoint = ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)
    callbacks = [getLearnRateCallback(cfg), checkpoint]

    history = model.fit(ds_train,
                        validation_data=ds_val,
                        verbose=True,
                        epochs=200,
                        class_weight=class_weights,
                        callbacks=callbacks)

    return history
history = learnModel(model, train_batches, cfg, valid_batches)

# %%
model.load_weights('Skin_attent_weights_acc_att_ens2.h5')

# %%
predictions = model.predict(test_batches, steps=len(test_batches), verbose=0)

# %%
predictions = model.predict(test_batches, steps=len(test_batches), verbose=0)
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image 
y_true = test_batches.classes
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("Classification Report:")
print(report)
